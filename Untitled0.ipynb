# %% [markdown]
# <a href="https://colab.research.google.com/github/Matvezy/Body-Mesurments/blob/master/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount("/content/gdrive")
# Out:
# Mounted at /content/gdrive

# %%
# %cd /content/gdrive/MyDrive/AI_2025_512px_ArmsLegsBodyPropDotsFixed2
# Out:
# /content/gdrive/MyDrive/AI_2025_512px_ArmsLegsBodyPropDotsFixed2

# %%
import time
import cv2
import os
import random
import numpy as np
import matplotlib.pyplot as plt
from PIL import Image
import imutils
import matplotlib.image as mpimg
from collections import OrderedDict
from skimage import io, transform
from math import *
import xml.etree.ElementTree as ET 

import torch
import torchvision
import torch.nn as nn
import torch.optim as optim
import torch.nn.functional as F
import torchvision.transforms.functional as TF
from torchvision import datasets, models, transforms
from torch.utils.data import Dataset
from torch.utils.data import DataLoader

# %%
class Transforms():
    def __init__(self):
        pass
    
    def resize(self, image, landmarks, img_size):
        image = TF.resize(image, img_size)
        return image, landmarks

    def __call__(self, image, landmarks):
        image = Image.fromarray(image)
        image, landmarks = self.resize(image, landmarks, (512, 512))
        
        image = TF.to_tensor(image)
        image = TF.normalize(image, [0.5], [0.5])
        return image, landmarks

# %%
class FaceLandmarksDataset(Dataset):

    def __init__(self, transform=None):

        tree = ET.parse('trainSide.xml')
        root = tree.getroot()
        self.image_filenames = []
        self.landmarks = []
        self.crops = []
        self.transform = transform
        for filename in root[1]:
            self.image_filenames.append(filename.attrib['front'])
            #self.crops.append(filename[0].attrib)

            landmark = []
            for num in range(6):
                x_coordinate = int(filename[num].attrib['x'])
                y_coordinate = int(filename[num].attrib['y'])
                landmark.append([x_coordinate, y_coordinate])
            self.landmarks.append(landmark)

        self.landmarks = np.array(self.landmarks).astype('float32')     

        assert len(self.image_filenames) == len(self.landmarks)

    def __len__(self):
        return len(self.image_filenames)

    def __getitem__(self, index):
        image = cv2.imread(self.image_filenames[index], 0)
        landmarks = self.landmarks[index]
        if self.transform:
            image, landmarks = self.transform(image, landmarks)

        return image, landmarks

dataset = FaceLandmarksDataset(Transforms())

# %%
print(dataset.image_filenames)
image, landmarks = dataset[2011] 
plt.figure(figsize=(10, 10))
plt.imshow(image.squeeze(), cmap='gray');
plt.scatter(landmarks[:,0], landmarks[:,1], s=8);
# Out:
# ['AITrainingLib/1/Side.png', 'AITrainingLib/2/Side.png', 'AITrainingLib/3/Side.png', 'AITrainingLib/4/Side.png', 'AITrainingLib/5/Side.png', 'AITrainingLib/6/Side.png', 'AITrainingLib/7/Side.png', 'AITrainingLib/8/Side.png', 'AITrainingLib/9/Side.png', 'AITrainingLib/10/Side.png', 'AITrainingLib/11/Side.png', 'AITrainingLib/12/Side.png', 'AITrainingLib/13/Side.png', 'AITrainingLib/14/Side.png', 'AITrainingLib/15/Side.png', 'AITrainingLib/16/Side.png', 'AITrainingLib/17/Side.png', 'AITrainingLib/18/Side.png', 'AITrainingLib/19/Side.png', 'AITrainingLib/20/Side.png', 'AITrainingLib/21/Side.png', 'AITrainingLib/22/Side.png', 'AITrainingLib/23/Side.png', 'AITrainingLib/24/Side.png', 'AITrainingLib/25/Side.png', 'AITrainingLib/26/Side.png', 'AITrainingLib/27/Side.png', 'AITrainingLib/28/Side.png', 'AITrainingLib/29/Side.png', 'AITrainingLib/30/Side.png', 'AITrainingLib/31/Side.png', 'AITrainingLib/32/Side.png', 'AITrainingLib/33/Side.png', 'AITrainingLib/34/Side.png', 'AITrainingLib/35/Side.png', 'AITrainingLib/36/Side.png', 'AITrainingLib/37/Side.png', 'AITrainingLib/38/Side.png', 'AITrainingLib/39/Side.png', 'AITrainingLib/40/Side.png', 'AITrainingLib/41/Side.png', 'AITrainingLib/42/Side.png', 'AITrainingLib/43/Side.png', 'AITrainingLib/44/Side.png', 'AITrainingLib/45/Side.png', 'AITrainingLib/46/Side.png', 'AITrainingLib/47/Side.png', 'AITrainingLib/48/Side.png', 'AITrainingLib/49/Side.png', 'AITrainingLib/50/Side.png', 'AITrainingLib/51/Side.png', 'AITrainingLib/52/Side.png', 'AITrainingLib/53/Side.png', 'AITrainingLib/54/Side.png', 'AITrainingLib/55/Side.png', 'AITrainingLib/56/Side.png', 'AITrainingLib/57/Side.png', 'AITrainingLib/58/Side.png', 'AITrainingLib/59/Side.png', 'AITrainingLib/60/Side.png', 'AITrainingLib/61/Side.png', 'AITrainingLib/62/Side.png', 'AITrainingLib/63/Side.png', 'AITrainingLib/64/Side.png', 'AITrainingLib/65/Side.png', 'AITrainingLib/66/Side.png', 'AITrainingLib/67/Side.png', 'AITrainingLib/68/Side.png', 'AITrainingLib/69/Side.png', 'AITrainingLib/70/Side.png', 'AITrainingLib/71/Side.png', 'AITrainingLib/72/Side.png', 'AITrainingLib/73/Side.png', 'AITrainingLib/74/Side.png', 'AITrainingLib/75/Side.png', 'AITrainingLib/76/Side.png', 'AITrainingLib/77/Side.png', 'AITrainingLib/78/Side.png', 'AITrainingLib/79/Side.png', 'AITrainingLib/80/Side.png', 'AITrainingLib/81/Side.png', 'AITrainingLib/82/Side.png', 'AITrainingLib/83/Side.png', 'AITrainingLib/84/Side.png', 'AITrainingLib/85/Side.png', 'AITrainingLib/86/Side.png', 'AITrainingLib/87/Side.png', 'AITrainingLib/88/Side.png', 'AITrainingLib/89/Side.png', 'AITrainingLib/90/Side.png', 'AITrainingLib/91/Side.png', 'AITrainingLib/92/Side.png', 'AITrainingLib/93/Side.png', 'AITrainingLib/94/Side.png', 'AITrainingLib/95/Side.png', 'AITrainingLib/96/Side.png', 'AITrainingLib/97/Side.png', 'AITrainingLib/98/Side.png', 'AITrainingLib/99/Side.png', 'AITrainingLib/100/Side.png', 'AITrainingLib/101/Side.png', 'AITrainingLib/102/Side.png', 'AITrainingLib/103/Side.png', 'AITrainingLib/104/Side.png', 'AITrainingLib/105/Side.png', 'AITrainingLib/106/Side.png', 'AITrainingLib/107/Side.png', 'AITrainingLib/108/Side.png', 'AITrainingLib/109/Side.png', 'AITrainingLib/110/Side.png', 'AITrainingLib/111/Side.png', 'AITrainingLib/112/Side.png', 'AITrainingLib/113/Side.png', 'AITrainingLib/114/Side.png', 'AITrainingLib/115/Side.png', 'AITrainingLib/116/Side.png', 'AITrainingLib/117/Side.png', 'AITrainingLib/118/Side.png', 'AITrainingLib/119/Side.png', 'AITrainingLib/120/Side.png', 'AITrainingLib/121/Side.png', 'AITrainingLib/122/Side.png', 'AITrainingLib/123/Side.png', 'AITrainingLib/124/Side.png', 'AITrainingLib/125/Side.png', 'AITrainingLib/126/Side.png', 'AITrainingLib/127/Side.png', 'AITrainingLib/128/Side.png', 'AITrainingLib/129/Side.png', 'AITrainingLib/130/Side.png', 'AITrainingLib/131/Side.png', 'AITrainingLib/132/Side.png', 'AITrainingLib/133/Side.png', 'AITrainingLib/134/Side.png', 'AITrainingLib/135/Side.png', 'AITrainingLib/136/Side.png', 'AITrainingLib/137/Side.png ...

# %%
# split the dataset into validation and test sets
len_valid_set = int(0.1*len(dataset))
len_train_set = len(dataset) - len_valid_set

print("The length of Train set is {}".format(len_train_set))
print("The length of Valid set is {}".format(len_valid_set))

train_dataset , valid_dataset,  = torch.utils.data.random_split(dataset , [len_train_set, len_valid_set])

# shuffle and batch the datasets
train_loader = torch.utils.data.DataLoader(train_dataset, batch_size=64, shuffle=True, num_workers=4)
valid_loader = torch.utils.data.DataLoader(valid_dataset, batch_size=8, shuffle=True, num_workers=4)
# Out:
# The length of Train set is 1823
# The length of Valid set is 202

# %%
images, landmarks = next(iter(train_loader))

print(images.shape)
print(landmarks.shape)
# Out:
# torch.Size([64, 1, 512, 512])
# torch.Size([64, 6, 2])

# %%
class Network(nn.Module):
    def __init__(self,num_classes=12):
        super().__init__()
        self.model_name='resnet34'
        self.model=models.resnet34()
        self.model.conv1=nn.Conv2d(1, 64, kernel_size=7, stride=2, padding=3, bias=False)
        self.model.fc=nn.Linear(self.model.fc.in_features, num_classes)
        
    def forward(self, x):
        x=self.model(x)
        return x

# %%
import sys

def print_overwrite(step, total_step, loss, operation):
    sys.stdout.write('\r')
    if operation == 'train':
        sys.stdout.write("Train Steps: %d/%d  Loss: %.4f " % (step, total_step, loss))   
    else:
        sys.stdout.write("Valid Steps: %d/%d  Loss: %.4f " % (step, total_step, loss))
        
    sys.stdout.flush()

# %%
import torch, gc

gc.collect()
torch.cuda.empty_cache()

# %%
torch.autograd.set_detect_anomaly(True)
network = Network()
network.load_state_dict(torch.load('front_landmarks2.pth')) 
network.cuda()

criterion = nn.MSELoss()
optimizer = optim.Adam(network.parameters(), lr=0.01)

loss_min = np.inf
num_epochs = 500   
start_time = time.time()
for epoch in range(1,num_epochs+1):
    
    loss_train = 0
    loss_valid = 0
    running_loss = 0
    
    network.train()
    #network.load_state_dict(torch.load('front_landmarks.pth')) 
    for step in range(1,len(train_loader)+1):
        for images, landmarks in train_loader:
          if torch.cuda.is_available():
            images = images.cuda()
            landmarks = landmarks.view(landmarks.size(0),-1).cuda()  
        
        
        predictions = network(images)
        
        # clear all the gradients before calculating them
        optimizer.zero_grad()
        
        # find the loss for the current step
        loss_train_step = criterion(predictions, landmarks)
        
        # calculate the gradients
        loss_train_step.backward()
        
        # update the parameters
        optimizer.step()
        
        loss_train += loss_train_step.item()
        running_loss = loss_train/step
        
        print_overwrite(step, len(train_loader), running_loss, 'train')
        
    network.eval() 
    with torch.no_grad():
        
        for step in range(1,len(valid_loader)+1):
            
            images, landmarks = next(iter(valid_loader))
        
            images = images.cuda()
            landmarks = landmarks.view(landmarks.size(0),-1).cuda()
        
            predictions = network(images)

            # find the loss for the current step
            loss_valid_step = criterion(predictions, landmarks)

            loss_valid += loss_valid_step.item()
            running_loss = loss_valid/step

            print_overwrite(step, len(valid_loader), running_loss, 'valid')
    
    loss_train /= len(train_loader)
    loss_valid /= len(valid_loader)
    
    print('\n--------------------------------------------------')
    print('Epoch: {}  Train Loss: {:.4f}  Valid Loss: {:.4f}'.format(epoch, loss_train, loss_valid))
    print('--------------------------------------------------')
    
    if loss_valid < loss_min:
        loss_min = loss_valid
        torch.save(network.state_dict(), 'front_landmarks3.pth') 
        print("\nMinimum Validation Loss of {:.4f} at epoch {}/{}".format(loss_min, epoch, num_epochs))
        print('Model Saved\n')
     
print('Training Complete')
print("Total Elapsed Time : {} s".format(time.time()-start_time))
# Out:
# Valid Steps: 26/26  Loss: 22.5851
# --------------------------------------------------
# Epoch: 1  Train Loss: 18.9135  Valid Loss: 22.5851
# --------------------------------------------------
#
# Minimum Validation Loss of 22.5851 at epoch 1/500
# Model Saved
#
# Valid Steps: 26/26  Loss: 17.1974
# --------------------------------------------------
# Epoch: 2  Train Loss: 8.8486  Valid Loss: 17.1974
# --------------------------------------------------
#
# Minimum Validation Loss of 17.1974 at epoch 2/500
# Model Saved
#
# Valid Steps: 26/26  Loss: 47.6709
# --------------------------------------------------
# Epoch: 3  Train Loss: 8.6908  Valid Loss: 47.6709
# --------------------------------------------------
# Valid Steps: 26/26  Loss: 771.4398
# --------------------------------------------------
# Epoch: 4  Train Loss: 11.0917  Valid Loss: 771.4398
# --------------------------------------------------
# Valid Steps: 26/26  Loss: 13.0878
# --------------------------------------------------
# Epoch: 5  Train Loss: 4.8166  Valid Loss: 13.0878
# --------------------------------------------------
#
# Minimum Validation Loss of 13.0878 at epoch 5/500
# Model Saved
#
# Valid Steps: 26/26  Loss: 90.1505
# --------------------------------------------------
# Epoch: 6  Train Loss: 9.1744  Valid Loss: 90.1505
# --------------------------------------------------
# Valid Steps: 26/26  Loss: 92.9635
# --------------------------------------------------
# Epoch: 7  Train Loss: 8.7910  Valid Loss: 92.9635
# --------------------------------------------------
# Valid Steps: 26/26  Loss: 161.0794
# --------------------------------------------------
# Epoch: 8  Train Loss: 11.1138  Valid Loss: 161.0794
# --------------------------------------------------
# Valid Steps: 26/26  Loss: 1306.8994
# --------------------------------------------------
# Epoch: 9  Train Loss: 13.7460  Valid Loss: 1306.8994
# --------------------------------------------------
# Valid Steps: 26/26  Loss: 26.2068
# --------------------------------------------------
# Epoch: 10  Train Loss: 7.0202  Valid Loss: 26.2068
# --------------------------------------------------
# Valid Steps: 26/26  Loss: 114.1331
# --------------------------------------------------
# Epoch: 11  Train Loss: 10.0438  Valid Loss: 114.1331
# --------------------------------------------------
# Valid Steps: 26/26  Loss: 50.8330
# --------------------------------------------------
# Epoch: 12  Train Loss: 8.8402  Valid Loss: 50.8330
# --------------------------------------------------
# Valid Steps: 26/26  Loss: 35.2730
# --------------------------------------------------
# Epoch: 13  Train Loss: 7.3050  Valid Loss: 35.2730
# --------------------------------------------------
# Valid Steps: 26/26  Loss: 431.4652
# --------------------------------------------------
# Epoch: 14  Train Loss: 10.1791  Valid Loss: 431.4652
# --------------------------------------------------
# Valid Steps: 26/26  Loss: 135.0283
# --------------------------------------------------
# Epoch: 15  Train Loss: 12.4588  Valid Loss: 135.0283
# --------------------------------------------------
# Valid Steps: 26/26  Loss: 3.5421
# --------------------------------------------------
# Epoch: 16  Train Loss: 7.2189  Valid Loss: 3.5421
# --------------------------------------------------
#
# Minimum Validation Loss of 3.5421 at epoch 16/500
# Model Saved
#
# Valid Steps: 26/26  Loss: 1393.7600
# --------------------------------------------------
# Epoch: 17  Train Loss: 9.7204  Valid Loss: 1393.7600
# --------------------------------------------------
# Valid Steps: 26/26  Loss: 24.6112
# --------------------------------------------------
# Epoch: 18  Train Loss: 8.7004  Valid Loss: 24.6112
# --------------------------------------------------
# Valid Steps: 26/26  Loss: 28.6734
# --------------------------------------------------
# Epoch: 19  Train Loss: 8.3235  Valid Loss: 28.6734
# --------------------------------------------------
# Valid Steps: 26/26  Loss: 5.8039
# --------------------------------------------------
# Epoch: 20  Train Loss: 7.1499  Valid Loss: 5.8039
# --------------------------------------------------
# Valid Steps: 26/26  Loss: 5.4474
# --------------------------------------------------
# Epoch: 21  Train Loss: 6.3980  Valid Loss: 5.4474
# --------------------------------------------------
# Valid Steps: 16/26  Loss: 64.1140
# Traceback (most recent call last):
#   File "/usr/lib/python3.6/multiprocessing/util.py", line 262, in _run_finalizers
#     finalizer()
#   File "/usr/lib/python3.6/multiprocessing/util.py", line 186, in __call__
#     res = self._callback(*self._args, **self._kwargs)
#   File "/usr/lib/python3.6/shutil.py", line 490, in rmtree
#     onerror(os.rmdir, path, sys.exc_info())
#   File "/usr/lib/python3.6/shutil.py", line 488, in rmtree
#     os.rmdir(path)
# OSError: [Errno 39] Directory not empty: '/tmp/pymp-25zcyelw'
# Valid Steps: 26/26  Loss: 65.1695
# --------------------------------------------------
# Epoch: 22  Train Loss: 7.3948  Valid Loss: 65.1695
# --------------------------------------------------
# Valid Steps: 26/26  Loss: 88.6325
# --------------------------------------------------
# Epoch: 23  Train Loss: 7.6897  Valid Loss: 88.6325
# --------------------------------------------------
# Valid Steps: 26/26  Loss: 14.2932
# --------------------------------------------------
# Epoch: 24  Train Loss: 4.5915  Valid Loss: 14.2932
# --------------------------------------------------
# Valid Steps: 26/26  Loss: 29.1487
# --------------------------------------------------
# Epoch: 25  Train Loss: 5.4217  Valid Loss: 29.1487
# --------------------------------------------------
# Valid Steps: 26/26  Loss: 38.3299
# --------------------------------------------------
# Epoch: 26  Train Loss: 11.0560  Valid Loss: 38.3299
# --------------------------------------------------
# Valid Steps: 4/26  Loss: 580.8476
# Traceback (most recent call last):
#   File "/usr/lib/python3.6/multiprocessing/util.py", line 262, in _run_finalizers
#     finalizer()
#   File "/usr/lib/python3.6/multiprocessing/util.py", line 186, in __call__
#     res = self._callback(*self._args, **self._kwargs)
#   File "/usr/lib/python3.6/shutil.py", line 490, in rmtree
#     onerror(os.rmdir, path, sys.exc_info())
#   File "/usr/lib/python3.6/shutil.py", line 488, in rmtree
#     os.rmdir(path)
# OSError: [Errno 39] Directory not empty: '/tmp/pymp-xni6h_sn'
# Valid Steps: 26/26  Loss: 615.4743
# --------------------------------------------------
# Epoch: 27  Train Loss: 10.7777  Valid Loss: 615.4743
# --------------------------------------------------
# Valid Steps: 26/26  Loss: 1501.4567
# --------------------------------------------------
# Epoch: 28  Train Loss: 11.8638  Valid Loss: 1501.4567
# --------------------------------------------------
# Valid Steps: 26/26  Loss: 151.8729
# --------------------------------------------------
# Epoch: 29  Train Loss: 5.1198  Valid Loss: 151.8729
# --------------------------------------------------
# Valid Steps: 26/26  Loss: 103.6617
# --------------------------------------------------
# Epoch: 30  Train Loss: 9.1222  Valid Loss: 103.6617
# --------------------------------------------------
# Valid Steps: 26/26  Loss: 9.5652
# --------------------------------------------------
# Epoch: 31  Train Loss: 7.6549  Valid Loss: 9.5652
# --------------------------------------------------
# Valid Steps: 26/26  Loss: 29.6983
# --------------------------------------------------
# Epoch: 32  Train Loss: 6.6558  Valid Loss: 29.6983
# --------------------------------------------------
# Valid Steps: 26/26  Loss: 32.1423
# --------------------------------------------------
# Epoch: 33  Train Loss: 7.2276  Valid Loss: 32.1423
# --------------------------------------------------
# Valid Steps: 26/26  Loss: 74.6563
# --------------------------------------------------
# Epoch: 34  Train Loss: 9.1393  Valid Loss: 74.6563
# --------------------------------------------------
# Valid Steps: 26/26  Loss: 49.2215
# --------------------------------------------------
# Epoch: 35  Train Loss: 8.9981  Valid Loss: 49.2215
# --------------------------------------------------
# Valid Steps: 26/26  Loss: 38.0453
# --------------------------------------------------
# Epoch: 36  Train Loss: 16.7390  Valid Loss: 38.0453
# --------------------------------------------------
# Valid Steps: 26/26  Loss: 158.6649
# --------------------------------------------------
# Epoch: 37  Train Loss: 7.8378  Valid Loss: 158.6649
# --------------------------------------------------
# Valid Steps: 26/26  Loss: 18.2802
# --------------------------------------------------
# Epoch: 38  Train Loss: 6.9361  Valid Loss: 18.2802
# --------------------------------------------------
# Valid Steps: 26/26  Loss: 144.9439
# --------------------------------------------------
# Epoch: 39  Train Loss: 7.9047  Valid Loss: 144.9439
# --------------------------------------------------
# Valid Steps: 26/26  Loss: 515.1167
# --------------------------------------------------
# Epoch: 40  Train Loss: 9.2204  Valid Loss: 515.1167
# --------------------------------------------------
# Valid Steps: 26/26  Loss: 24.9505
# --------------------------------------------------
# Epoch: 41  Train Loss: 8.1593  Valid Loss: 24.9505
# --------------------------------------------------
# Valid Steps: 26/26  Loss: 40.8186
# --------------------------------------------------
# Epoch: 42  Train Loss: 7.7871  Valid Loss: 40.8186
# --------------------------------------------------
# Valid Steps: 26/26  Loss: 44.6548
# --------------------------------------------------
# Epoch: 43  Train Loss: 6.5333  Valid Loss: 44.6548
# --------------------------------------------------
# Valid Steps: 26/26  Loss: 50.4149
# --------------------------------------------------
# Epoch: 44  Train Loss: 5.7964  Valid Loss: 50.4149
# --------------------------------------------------
# Valid Steps: 26/26  Loss: 25.9898
# --------------------------------------------------
# Epoch: 45  Train Loss: 7.8124  Valid Loss: 25.9898
# --------------------------------------------------
# Valid Steps: 26/26  Loss: 147.9243
# --------------------------------------------------
# Epoch: 46  Train Loss: 8.8416  Valid Loss: 147.9243
# --------------------------------------------------
# Valid Steps: 26/26  Loss: 9.3534
# --------------------------------------------------
# Epoch: 47  Train Loss: 7.8220  Valid Loss: 9.3534
# --------------------------------------------------
# Valid Steps: 26/26  Loss: 335.2884
# --------------------------------------------------
# Epoch: 48  Train Loss: 7.0420  Valid Loss: 335.2884
# --------------------------------------------------
# Valid Steps: 26/26  Loss: 148.9431
# --------------------------------------------------
# Epoch: 49  Train Loss: 6.1587  Valid Loss: 148.9431
# --------------------------------------------------
# Valid Steps: 26/26  Loss: 261.7843
# --------------------------------------------------
# Epoch: 50  Train Loss: 6.0680  Valid Loss: 261.7843
# --------------------------------------------------
# Valid Steps: 26/26  Loss: 127.3660
# --------------------------------------------------
# Epoch: 51  Train Loss: 5.4214  Valid Loss: 127.3660
# --------------------------------------------------
# Valid Steps: 26/26  Loss: 16.2367
# --------------------------------------------------
# Epoch: 52  Train Loss: 7.0398  Valid Loss: 16.2367
# --------------------------------------------------
# Valid Steps: 26/26  Loss: 3.7415
# --------------------------------------------------
# Epoch: 53  Train Loss: 9.2301  Valid Loss: 3.7415
# --------------------------------------------------
# Valid Steps: 26/26  Loss: 33.7205
# --------------------------------------------------
# Epoch: 54  Train Loss: 7.6234  Valid Loss: 33.7205
# --------------------------------------------------
# Valid Steps: 26/26  Loss: 32.5148
# --------------------------------------------------
# Epoch: 55  Train Loss: 6.7713  Valid Loss: 32.5148
# --------------------------------------------------
# Valid Steps: 26/26  Loss: 85.7471
# --------------------------------------------------
# Epoch: 56  Train Loss: 5.5615  Valid Loss: 85.7471
# --------------------------------------------------
# Valid Steps: 7/26  Loss: 9.5646
# Traceback (most recent call last):
#   File "/usr/lib/python3.6/multiprocessing/util.py", line 262, in _run_finalizers
#     finalizer()
#   File "/usr/lib/python3.6/multiprocessing/util.py", line 186, in __call__
#     res = self._callback(*self._args, **self._kwargs)
#   File "/usr/lib/python3.6/shutil.py", line 490, in rmtree
#     onerror(os.rmdir, path, sys.exc_info())
#   File "/usr/lib/python3.6/shutil.py", line 488, in rmtree
#     os.rmdir(path)
# OSError: [Errno 39] Directory not empty: '/tmp/pymp-ywp4rgfb'
# Valid Steps: 26/26  Loss: 9.7386
# --------------------------------------------------
# Epoch: 57  Train Loss: 7.2394  Valid Loss: 9.7386
# --------------------------------------------------
# Valid Steps: 26/26  Loss: 63.8625
# --------------------------------------------------
# Epoch: 58  Train Loss: 9.1547  Valid Loss: 63.8625
# --------------------------------------------------
# Valid Steps: 26/26  Loss: 6.6064
# --------------------------------------------------
# Epoch: 59  Train Loss: 5.7085  Valid Loss: 6.6064
# --------------------------------------------------
# Valid Steps: 26/26  Loss: 7.6265
# --------------------------------------------------
# Epoch: 60  Train Loss: 5.6987  Valid Loss: 7.6265
# --------------------------------------------------
# Valid Steps: 26/26  Loss: 9.6588
# --------------------------------------------------
# Epoch: 61  Train Loss: 5.9091  Valid Loss: 9.6588
# --------------------------------------------------
# Valid Steps: 26/26  Loss: 159.2334
# --------------------------------------------------
# Epoch: 62  Train Loss: 6.2687  Valid Loss: 159.2334
# --------------------------------------------------
# Valid Steps: 26/26  Loss: 1031.5632
# --------------------------------------------------
# Epoch: 63  Train Loss: 6.7660  Valid Loss: 1031.5632
# --------------------------------------------------
# Valid Steps: 26/26  Loss: 14.1481
# --------------------------------------------------
# Epoch: 64  Train Loss: 5.4034  Valid Loss: 14.1481
# --------------------------------------------------
# Valid Steps: 26/26  Loss: 20.3308
# --------------------------------------------------
# Epoch: 65  Train Loss: 5.2623  Valid Loss: 20.3308
# --------------------------------------------------
# Valid Steps: 26/26  Loss: 9.6486
# --------------------------------------------------
# Epoch: 66  Train Loss: 5.3230  Valid Loss: 9.6486
# --------------------------------------------------
# Valid Steps: 26/26  Loss: 17.3134
# --------------------------------------------------
# Epoch: 67  Train Loss: 5.1359  Valid Loss: 17.3134
# --------------------------------------------------
# Valid Steps: 26/26  Loss: 116.1712
# --------------------------------------------------
# Epoch: 68  Train Loss: 4.4724  Valid Loss: 116.1712
# --------------------------------------------------
# Valid Steps: 26/26  Loss: 3.4872
# --------------------------------------------------
# Epoch: 69  Train Loss: 6.5828  Valid Loss: 3.4872
# --------------------------------------------------
#
# Minimum Validation Loss of 3.4872 at epoch 69/500
# Model Saved
#
# Valid Steps: 26/26  Loss: 64.1867
# --------------------------------------------------
# Epoch: 70  Train Loss: 6.1353  Valid Loss: 64.1867
# --------------------------------------------------
# Valid Steps: 26/26  Loss: 71.2827
# --------------------------------------------------
# Epoch: 71  Train Loss: 9.1247  Valid Loss: 71.2827
# --------------------------------------------------
# Valid Steps: 26/26  Loss: 8.7453
# --------------------------------------------------
# Epoch: 72  Train Loss: 6.2680  Valid Loss: 8.7453
# --------------------------------------------------
# Valid Steps: 26/26  Loss: 10.9119
# --------------------------------------------------
# Epoch: 73  Train Loss: 5.1455  Valid Loss: 10.9119
# --------------------------------------------------
# Valid Steps: 26/26  Loss: 89.2897
# --------------------------------------------------
# Epoch: 74  Train Loss: 11.4474  Valid Loss: 89.2897
# --------------------------------------------------
# Valid Steps: 26/26  Loss: 18.4151
# --------------------------------------------------
# Epoch: 75  Train Loss: 6.0572  Valid Loss: 18.4151
# --------------------------------------------------
# Valid Steps: 26/26  Loss: 5.6710
# --------------------------------------------------
# Epoch: 76  Train Loss: 6.5595  Valid Loss: 5.6710
# --------------------------------------------------
# Valid Steps: 26/26  Loss: 44.7358
# --------------------------------------------------
# Epoch: 77  Train Loss: 4.9591  Valid Loss: 44.7358
# --------------------------------------------------
# Valid Steps: 26/26  Loss: 26.9767
# --------------------------------------------------
# Epoch: 78  Train Loss: 8.2638  Valid Loss: 26.9767
# --------------------------------------------------
# Valid Steps: 26/26  Loss: 23.8515
# --------------------------------------------------
# Epoch: 79  Train Loss: 4.5954  Valid Loss: 23.8515
# --------------------------------------------------
# Valid Steps: 26/26  Loss: 2.5703
# --------------------------------------------------
# Epoch: 80  Train Loss: 4.9421  Valid Loss: 2.5703
# --------------------------------------------------
#
# Minimum Validation Loss of 2.5703 at epoch 80/500
# Model Saved
#
# Valid Steps: 26/26  Loss: 137.4915
# --------------------------------------------------
# Epoch: 81  Train Loss: 5.5251  Valid Loss: 137.4915
# --------------------------------------------------
# Valid Steps: 26/26  Loss: 39.1495
# --------------------------------------------------
# Epoch: 82  Train Loss: 5.3555  Valid Loss: 39.1495
# --------------------------------------------------
# Valid Steps: 26/26  Loss: 36.9294
# --------------------------------------------------
# Epoch: 83  Train Loss: 4.6024  Valid Loss: 36.9294
# --------------------------------------------------
# Valid Steps: 26/26  Loss: 4.9485
# --------------------------------------------------
# Epoch: 84  Train Loss: 4.0178  Valid Loss: 4.9485
# --------------------------------------------------
# Valid Steps: 26/26  Loss: 109.8879
# --------------------------------------------------
# Epoch: 85  Train Loss: 5.6593  Valid Loss: 109.8879
# --------------------------------------------------
# Valid Steps: 26/26  Loss: 18.2051
# --------------------------------------------------
# Epoch: 86  Train Loss: 6.6183  Valid Loss: 18.2051
# --------------------------------------------------
# Valid Steps: 26/26  Loss: 9.8923
# --------------------------------------------------
# Epoch: 87  Train Loss: 5.8013  Valid Loss: 9.8923
# --------------------------------------------------
# Valid Steps: 26/26  Loss: 14.8912
# --------------------------------------------------
# Epoch: 88  Train Loss: 4.3060  Valid Loss: 14.8912
# --------------------------------------------------
# Valid Steps: 26/26  Loss: 41.9836
# --------------------------------------------------
# Epoch: 89  Train Loss: 5.4207  Valid Loss: 41.9836
# --------------------------------------------------
# Valid Steps: 26/26  Loss: 292.6937
# --------------------------------------------------
# Epoch: 90  Train Loss: 7.0308  Valid Loss: 292.6937
# --------------------------------------------------
# Valid Steps: 26/26  Loss: 8.6107
# --------------------------------------------------
# Epoch: 91  Train Loss: 5.4354  Valid Loss: 8.6107
# --------------------------------------------------
# Valid Steps: 26/26  Loss: 20.4875
# --------------------------------------------------
# Epoch: 92  Train Loss: 6.3204  Valid Loss: 20.4875
# --------------------------------------------------
# Valid Steps: 26/26  Loss: 145.4040
# --------------------------------------------------
# Epoch: 93  Train Loss: 4.0255  Valid Loss: 145.4040
# --------------------------------------------------
# Valid Steps: 26/26  Loss: 47.2762
# --------------------------------------------------
# Epoch: 94  Train Loss: 4.5883  Valid Loss: 47.2762
# --------------------------------------------------
# Valid Steps: 26/26  Loss: 9.9273
# --------------------------------------------------
# Epoch: 95  Train Loss: 6.7816  Valid Loss: 9.9273
# --------------------------------------------------
# Valid Steps: 26/26  Loss: 124.4289
# --------------------------------------------------
# Epoch: 96  Train Loss: 9.4355  Valid Loss: 124.4289
# --------------------------------------------------
# Valid Steps: 26/26  Loss: 176.2388
# --------------------------------------------------
# Epoch: 97  Train Loss: 5.6007  Valid Loss: 176.2388
# --------------------------------------------------
# Valid Steps: 26/26  Loss: 7.0272
# --------------------------------------------------
# Epoch: 98  Train Loss: 6.7254  Valid Loss: 7.0272
# --------------------------------------------------
# Valid Steps: 26/26  Loss: 26.2506
# --------------------------------------------------
# Epoch: 99  Train Loss: 4.9991  Valid Loss: 26.2506
# --------------------------------------------------
# Valid Steps: 26/26  Loss: 28.8278
# --------------------------------------------------
# Epoch: 100  Train Loss: 11.3960  Valid Loss: 28.8278
# --------------------------------------------------
# Valid Steps: 26/26  Loss: 2.8151
# --------------------------------------------------
# Epoch: 101  Train Loss: 6.5763  Valid Loss: 2.8151
# --------------------------------------------------
# Valid Steps: 26/26  Loss: 11.4599
# --------------------------------------------------
# Epoch: 102  Train Loss: 7.0947  Valid Loss: 11.4599
# --------------------------------------------------
# Valid Steps: 26/26  Loss: 18.9255
# --------------------------------------------------
# Epoch: 103  Train Loss: 6.6980  Valid Loss: 18.9255
# --------------------------------------------------
# Valid Steps: 26/26  Loss: 7.8668
# --------------------------------------------------
# Epoch: 104  Train Loss: 7.2996  Valid Loss: 7.8668
# --------------------------------------------------
# Train Steps: 1/29  Loss: 3.2915

# %%
import pandas as pd

# %%
data = pd.read_csv("https://filtereddatasets.s3.amazonaws.com/Groceries_retail/Groceriesv2.csv")

# %%
df = pd.DataFrame(data)
df.head()
# Out:
#     Order_no  Prod_no  ... Unit_price Total_amt
# 0  OD_100034       15  ...      $4.66    $13.98
# 1  OD_100034       21  ...      $5.63    $56.30
# 2  OD_100034      121  ...      $4.29    $64.35
# 3  OD_100034      125  ...      $4.56    $77.52
# 4  OD_100034      156  ...      $5.50    $11.00
#
# [5 rows x 8 columns]

# %%
prod_names = df['Prod_name'].unique()
appearences = {key: {key1:0 for key1 in [i for i in prod_names if i != key]} for key in prod_names}
appearences['Icecream Cone - Areo Chocolate']
# Out:
# {'Alize Sunset': 0,
#  'Amaretto': 0,
#  'Amarula Cream': 0,
#  'Anchovy In Oil': 0,
#  'Anisette - Mcguiness': 0,
#  'Appetizer - Assorted Box': 0,
#  'Appetizer - Cheese Bites': 0,
#  'Appetizer - Escargot Puff': 0,
#  'Appetizer - Mini Egg Roll, Shrimp': 0,
#  'Appetizer - Sausage Rolls': 0,
#  'Appetizer - Seafood Assortment': 0,
#  'Appetizer - Southwestern': 0,
#  'Apple - Granny Smith': 0,
#  'Apple - Macintosh': 0,
#  'Apricots - Halves': 0,
#  'Apricots Fresh': 0,
#  'Artichokes - Knobless, White': 0,
#  'Aspic - Amber': 0,
#  'Aspic - Clear': 0,
#  'Assorted Desserts': 0,
#  'Avocado': 0,
#  'Bacardi Limon': 0,
#  'Bacardi Mojito': 0,
#  'Bacon Strip Precooked': 0,
#  'Bag Clear 10 Lb': 0,
#  'Bagel - Sesame Seed Presliced': 0,
#  'Bagelers': 0,
#  'Bagels Poppyseed': 0,
#  'Baking Soda': 0,
#  'Banana - Leaves': 0,
#  'Bandage - Fexible 1x3': 0,
#  'Bar Bran Honey Nut': 0,
#  'Bar Special K': 0,
#  'Basil - Dry, Rubbed': 0,
#  'Basil - Fresh': 0,
#  'Basil - Pesto Sauce': 0,
#  'Beans - Butter Lrg Lima': 0,
#  'Beans - Fava Fresh': 0,
#  'Beans - Fava, Canned': 0,
#  'Beans - Kidney, Canned': 0,
#  'Beans - Turtle, Black, Dry': 0,
#  'Beef - Bones, Marrow': 0,
#  'Beef - Bresaola': 0,
#  'Beef - Diced': 0,
#  'Beef - Eye Of Round': 0,
#  'Beef - Ground Medium': 0,
#  'Beef - Ground, Extra Lean, Fresh': 0,
#  'Beef - Ox Tail, Frozen': 0,
#  'Beef - Prime Rib Aaa': 0,
#  'Beef - Rib Eye Aaa': 0,
#  'Beef - Roasted, Cooked': 0,
#  'Beef - Rouladin, Sliced': 0,
#  'Beef - Striploin': 0,
#  'Beef - Tenderloin': 0,
#  'Beef - Texas Style Burger': 0,
#  'Beef - Top Sirloin': 0,
#  'Beef - Top Sirloin - Aaa': 0,
#  'Beef Cheek Fresh': 0,
#  'Beef Dry Aged Tenderloin Aaa': 0,
#  'Beef Striploin Aaa': 0,
#  'Beef Wellington': 0,
#  'Beer - Corona': 0,
#  'Beer - Creemore': 0,
#  'Beer - Fruli': 0,
#  'Beer - Guiness': 0,
#  'Beer - Labatt Blue': 0,
#  'Beer - Molson Excel': 0,
#  'Beer - Paulaner Hefeweisse': 0,
#  'Beer - Pilsner Urquell': 0,
#  'Beer - Rickards Red': 0,
#  'Beer - Sleemans Cream Ale': 0,
#  'Beer - Sleemans Honey Brown': 0,
#  'Beer - Steamwhistle': 0,
#  'Beets': 0,
#  'Beets - Mini Golden': 0,
#  'Black Currants': 0,
#  'Blue Curacao - Marie Brizard': 0,
#  'Blueberries - Frozen': 0,
#  'Bok Choy - Baby': 0,
#  'Bols Melon Liqueur': 0,
#  'Boogies': 0,
#  'Bread - 10 Grain Parisian': 0,
#  'Bread - Dark Rye': 0,
#  'Bread - Dark Rye, Loaf': 0,
#  'Bread - Focaccia Quarter': 0,
#  'Bread - French Baquette': 0,
#  'Bread - Italian Sesame Poly': 0,
#  'Bread - Kimel Stick Poly': 0,
#  'Bread - Mini Hamburger Bun': 0,
#  'Bread - Multigrain Oval': 0,
#  'Bread - Multigrain, Loaf': 0,
#  'Bread - Olive Dinner Roll': 0,
#  'Bread - Pain Au Liat X12': 0,
#  'Bread - Pita': 0,
#  'Bread - Pumpernickle, Rounds': 0,
#  'Bread - Raisin': 0,
#  'Bread - Raisin Walnut Pull': 0,
#  'Bread - Rosemary Focaccia': 0,
#  'Bread - Triangle White': 0,
#  'Bread - Wheat Baguette': 0,
#  'Bread Base - Gold Formel': 0,
#  'Bread Base - Toscano': 0,
#  'Bread Cranberry Foccacia': 0,
#  'Bread Fig And Almond': 0,
#  'Breadfruit': 0,
#  'Broccoli - Fresh': 0,
#  'Brocolinni - Gaylan, Chinese': 0,
#  'Broom - Angled': 0,
#  'Broom - Push': 0,
#  'Broom And Brush Rack Black': 0,
#  'Buffalo - Short Rib Fresh': 0,
#  'Buffalo - Striploin': 0,
#  'Bulgar': 0,
#  'Butter - Pod': 0,
#  'Butter - Salted, Micro': 0,
#  'Butter - Unsalted': 0,
#  'Butter Balls Salted': 0,
#  'Cabbage - Green': 0,
#  'Cabbage - Nappa': 0,
#  'Cabbage - Savoy': 0,
#  'Cake - Cake Sheet Macaroon': 0,
#  'Cake - French Pear Tart': 0,
#  'Cake - Miini Cheesecake Cherry': 0,
#  'Cake - Sheet Strawberry': 0,
#  'Cake Sheet Combo Party Pack': 0,
#  'Calypso - Black Cherry Lemonade': 0,
#  'Campari': 0,
#  'Canadian Emmenthal': 0,
#  'Capers - Pickled': 0,
#  'Capon - Breast, Wing On': 0,
#  'Carbonated Water - Lemon Lime': 0,
#  'Carbonated Water - White Grape': 0,
#  'Carrots - Purple, Organic': 0,
#  'Carroway Seed': 0,
#  'Cattail Hearts': 0,
#  'Cauliflower': 0,
#  'Celery': 0,
#  'Celery Root': 0,
#  'Cheese - Augre Des Champs': 0,
#  'Cheese - Brie, Triple Creme': 0,
#  'Cheese - Camembert': 0,
#  'Cheese - Cottage Cheese': 0,
#  'Cheese - Cream Cheese': 0,
#  'Cheese - Fontina': 0,
#  'Cheese - Goat': 0,
#  'Cheese - Gouda Smoked': 0,
#  'Cheese - Grana Padano': 0,
#  'Cheese - Manchego, Spanish': 0,
#  'Cheese - Marble': 0,
#  'Cheese - Montery Jack': 0,
#  'Cheese - Mozzarella, Buffalo': 0,
#  'Cheese - Parmesan Grated': 0,
#  'Cheese - Perron Cheddar': 0,
#  'Cheese - Pied De Vents': 0,
#  'Cheese - Provolone': 0,
#  'Cheese - Sheep Milk': 0,
#  'Cheese - Shred Cheddar / Mozza': 0,
#  'Cheese - St. Andre': 0,
#  'Cheese - Stilton': 0,
#  'Cheese - Swiss': 0,
#  'Cheese - Victor Et Berthold': 0,
#  'Cheese Cloth': 0,
#  'Cheese Cloth No 100': 0,
#  'Cherries - Bing, Canned': 0,
#  'Cherries - Fresh': 0,
#  'Cherries - Frozen': 0,
#  'Cherries - Maraschino,jar': 0,
#  'Chevril': 0,
#  'Chicken - Base': 0,
#  'Chicken - Breast, 5 - 7 Oz': 0,
#  'Chicken - Diced, Cooked': 0,
#  'Chicken - Leg / Back Attach': 0,
#  'Chicken - Leg, Boneless': 0,
#  'Chicken - Whole Fryers': 0,
#  'Chicken - Wieners': 0,
#  'Chicken Giblets': 0,
#  'Chicken Thigh - Bone Out': 0,
#  'Chilli Paste, Hot Sambal Oelek': 0,
#  'Chinese Foods - Cantonese': 0,
#  'Chinese Foods - Thick Noodles': 0,
#  'Chinese Lemon Pork': 0,
#  'Chip - Potato Dill Pickle': 0,
#  'Chips - Potato Jalapeno': 0,
#  'Chips Potato Reg 43g': 0,
#  'Chocolate - Chips Compound': 0,
#  'Chocolate - Compound Coating': 0,
#  'Chocolate - Dark Callets': 0,
#  'Chocolate - Milk, Callets': 0,
#  'Chocolate - Pistoles, Lactee, Milk': 0,
#  'Chocolate - Pistoles, White': 0,
#  'Chocolate - Semi Sweet': 0,
#  'Chocolate - Semi Sweet, Calets': 0,
#  'Chocolate Liqueur - Godet White': 0,
#  'Chutney Sauce - Mango': 0,
#  'Cinnamon Buns Sticky': 0,
#  'Cinnamon Rolls': 0,
#  'Clam Nectar': 0,
#  'Cleaner - Lime Away': 0,
#  'Cleaner - Pine Sol': 0,
#  'Cocoa Butter': 0,
#  'Cocoa Powder - Dutched': 0,
#  'Cocoa Powder - Natural': 0,
#  'Coconut - Whole': 0,
#  'Coconut Milk - Unsweetened': 0,
#  'Cod - Black Whole Fillet': 0,
#  'Cod - Fillets': 0,
#  'Cod - Salted, Boneless': 0,
#  'Coffee - Cafe Moreno': 0,
#  'Coffee - Colombian, Portioned': 0,
#  'Coffee - Decafenated': 0,
#  'Coffee - Ristretto Coffee Capsule': 0,
#  'Coffee Cup 16oz Foam': 0,
#  'Coffee Decaf Colombian': 0,
#  'Coffee Swiss Choc Almond': 0,
#  'Cognac - Courvaisier': 0,
#  'Compound - Mocha': 0,
#  'Compound - Passion Fruit': 0,
#  'Compound - Rum': 0,
#  'Cookie - Oreo 100x2': 0,
#  'Cookie Dough - Chocolate Chip': 0,
#  'Cookies - Amaretto': 0,
#  'Cookies - Englishbay Chochip': 0,
#  'Cookies - Fortune': 0,
#  'Coriander - Ground': 0,
#  'Corn - Mini': 0,
#  'Corn - On The Cob': 0,
#  'Corn Meal': 0,
#  'Cornstarch': 0,
#  'Cotton Wet Mop 16 Oz': 0,
#  'Crab - Blue, Frozen': 0,
#  'Crab - Claws, Snow 16 - 24': 0,
#  'Crab - Meat': 0,
#  'Crackers - Graham': 0,
#  'Crackers - Soda / Saltins': 0,
#  'Crackers - Water': 0,
#  'Creme De Banane - Marie': 0,
#  'Creme De Menth - White': 0,
#  'Croissants Thaw And Serve': 0,
#  'Crush - Cream Soda': 0,
#  'Cumin - Whole': 0,
#  'Cup - 4oz Translucent': 0,
#  'Cup - 8oz Coffee Perforated': 0,
#  'Cup Translucent 9 Oz': 0,
#  'Curry Paste - Green Masala': 0,
#  'Dc - Frozen Momji': 0,
#  'Dc - Sakura Fu': 0,
#  'Devonshire Cream': 0,
#  'Dikon': 0,
#  'Dill Weed - Dry': 0,
#  'Dip - Tapenade': 0,
#  'Doilies - 5, Paper': 0,
#  'Doilies - 7, Paper': 0,
#  'Doilies - 8, Paper': 0,
#  'Dr. Pepper - 355ml': 0,
#  'Dried Apple': 0,
#  'Dried Cranberries': 0,
#  'Dried Peach': 0,
#  'Duck - Fat': 0,
#  'Duck - Legs': 0,
#  'Ecolab - Hand Soap Form Antibac': 0,
#  'Ecolab - Hobart Upr Prewash Arm': 0,
#  'Ecolab - Lime - A - Way 4/4 L': 0,
#  'Ecolab - Medallion': 0,
#  'Ecolab - Mikroklene 4/4 L': 0,
#  'Ecolab - Solid Fusion': 0,
#  'Ecolab Digiclean Mild Fm': 0,
#  'Eggplant - Asian': 0,
#  'Eggplant - Baby': 0,
#  'Eggplant Oriental': 0,
#  'Eggs - Extra Large': 0,
#  'Emulsifier': 0,
#  'Energy Drink': 0,
#  'Energy Drink - Franks Pineapple': 0,
#  'Extract - Rum': 0,
#  'Extract Vanilla Pure': 0,
#  'Fiddlehead - Frozen': 0,
#  'Filling - Mince Meat': 0,
#  'Filo Dough': 0,
#  'Fish - Atlantic Salmon, Cold': 0,
#  'Five Alive Citrus': 0,
#  'Flavouring - Orange': 0,
#  'Flavouring - Raspberry': 0,
#  'Flavouring Vanilla Artificial': 0,
#  'Flour - Buckwheat, Dark': 0,
#  'Flour - Corn, Fine': 0,
#  'Flour - Masa De Harina Mexican': 0,
#  'Flour - So Mix Cake White': 0,
#  'Flour - Strong': 0,
#  'Flour - Teff': 0,
#  'Flour Dark Rye': 0,
#  'Flower - Commercial Spider': 0,
#  'Flower - Daisies': 0,
#  'Flower - Dish Garden': 0,
#  'Flower - Leather Leaf Fern': 0,
#  'Flower - Potmums': 0,
#  'Foam Cup 6 Oz': 0,
#  'Foam Tray S2': 0,
#  'Foil Cont Round': 0,
#  'Fond - Chocolate': 0,
#  'Food Colouring - Blue': 0,
#  'Food Colouring - Pink': 0,
#  'Fork - Plastic': 0,
#  'French Pastries': 0,
#  'Fuji Apples': 0,
#  'Garbage Bag - Clear': 0,
#  'Garbage Bags - Black': 0,
#  'Garbage Bags - Clear': 0,
#  'Garlic Powder': 0,
#  'Gatorade - Orange': 0,
#  'Gelatine Leaves - Bulk': 0,
#  'Gelatine Leaves - Envelopes': 0,
#  'Gelatine Powder': 0,
#  'Gherkin': 0,
#  'Gin - Gilbeys London, Dry': 0,
#  'Glass - Wine, Plastic, Clear 5 Oz': 0,
#  'Glaze - Clear': 0,
#  'Glycerine': 0,
#  'Goat - Leg': 0,
#  'Goldschalger': 0,
#  'Gooseberry': 0,
#  'Goulash Seasoning': 0,
#  'Grouper - Fresh': 0,
#  'Haggis': 0,
#  'Ham - Cooked Bayonne Tinned': 0,
#  'Ham - Cooked Italian': 0,
#  'Ham - Procutinni': 0,
#  'Heavy Duty Dust Pan': 0,
#  'Higashimaru Usukuchi Soy': 0,
#  'Honey - Lavender': 0,
#  'Honey - Liquid': 0,
#  'Horseradish - Prepared': 0,
#  'Hot Chocolate - Individual': 0,
#  'Huck Towels White': 0,
#  'Huck White Towels': 0,
#  'Ice Cream - Fudge Bars': 0,
#  'Ice Cream Bar - Drumstick': 0,
#  'Ice Cream Bar - Hageen Daz To': 0,
#  'Icecream - Dstk Cml And Fdg': 0,
#  'Iced Tea - Lemon, 340ml': 0,
#  'Iced Tea - Lemon, 460 Ml': 0,
#  'Initation Crab Meat': 0,
#  'Instant Coffee': 0,
#  'Irish Cream - Baileys': 0,
#  'Irish Cream - Butterscotch': 0,
#  'Island Oasis - Magarita Mix': 0,
#  'Island Oasis - Pina Colada': 0,
#  'Island Oasis - Raspberry': 0,
#  'Island Oasis - Sweet And Sour Mix': 0,
#  'Island Oasis - Wildberry': 0,
#  'Jam - Apricot': 0,
#  'Jam - Blackberry, 20 Ml Jar': 0,
#  'Jam - Raspberry,jar': 0,
#  'Jam - Strawberry, 20 Ml Jar': 0,
#  'Jameson - Irish Whiskey': 0,
#  'Jello - Assorted': 0,
#  'Juice - Grapefruit, 341 Ml': 0,
#  'Juice - Mango': 0,
#  'Juice - Ocean Spray Kiwi': 0,
#  'Juice - Orange': 0,
#  'Juice - Orange 1.89l': 0,
#  'Juice - Orange, 341 Ml': 0,
#  'Juice - Orangina': 0,
#  'Juice - V8 Splash': 0,
#  'Kaffir Lime Leaves': 0,
#  'Kellogs Raisan Bran Bars': 0,
#  'Ketchup - Tomato': 0,
#  'Kiwano': 0,
#  'Kiwi': 0,
#  'Lamb - Bones': 0,
#  'Lamb - Leg, Bone In': 0,
#  'Lamb - Pieces, Diced': 0,
#  'Lamb - Sausage Casings': 0,
#  'Lamb - Shanks': 0,
#  'Lamb - Shoulder, Boneless': 0,
#  'Lamb - Whole, Frozen': 0,
#  'Lamb Rack Frenched Australian': 0,
#  'Lamb Shoulder Boneless Nz': 0,
#  'Latex Rubber Gloves Size 9': 0,
#  'Lemon Balm - Fresh': 0,
#  'Lemon Grass': 0,
#  'Lemonade - Pineapple Passion': 0,
#  'Lemons': 0,
#  'Lentils - Green, Dry': 0,
#  'Lentils - Red, Dry': 0,
#  'Lettuce - Baby Salad Greens': 0,
#  'Lettuce - Boston Bib - Organic': 0,
#  'Lettuce - Lambs Mash': 0,
#  'Lettuce - Romaine': 0,
#  'Lettuce - Treviso': 0,
#  'Lettuce Romaine Chopped': 0,
#  'Lid - 0090 Clear': 0,
#  'Lighter - Bbq': 0,
#  'Limes': 0,
#  'Liqueur Banana, Ramazzotti': 0,
#  'Loaf Pan - 2 Lb, Foil': 0,
#  'Lobster - Base': 0,
#  'Lobster - Cooked': 0,
#  'Lobster - Tail 6 Oz': 0,
#  'Longan': 0,
#  'Longos - Burritos': 0,
#  'Longos - Cheese Tortellini': 0,
#  'Longos - Chicken Cordon Bleu': 0,
#  'Longos - Chicken Curried': 0,
#  'Longos - Greek Salad': 0,
#  'Longos - Grilled Veg Sandwiches': 0,
#  'Lotus Leaves': 0,
#  'Lotus Root': 0,
#  'Lotus Rootlets - Canned': 0,
#  'Macaroons - Two Bite Choc': 0,
#  'Mace': 0,
#  'Madeira': 0,
#  'Maple Syrup': 0,
#  'Marzipan 50/50': 0,
#  'Mcgillicuddy Vanilla Schnap': 0,
#  'Mcguinness - Blue Curacao': 0,
#  'Meldea Green Tea Liquor': 0,
#  'Melon - Watermelon Yellow': 0,
#  'Mikes Hard Lemonade': 0,
#  'Milk - 2% 250 Ml': 0,
#  'Milk 2% 500 Ml': 0,
#  'Mini - Vol Au Vents': 0,
#  'Mint - Fresh': 0,
#  'Mints - Striped Red': 0,
#  'Miso Paste White': 0,
#  'Mix - Cocktail Strawberry Daiquiri': 0,
#  'Molasses - Fancy': 0,
#  'Monkfish - Fresh': 0,
#  'Monkfish Fresh - Skin Off': 0,
#  'Mop Head - Cotton, 24 Oz': 0,
#  'Mortadella': 0,
#  'Mountain Dew': 0,
#  'Mousse - Banana Chocolate': 0,
#  'Mousse - Mango': 0,
#  'Muffin - Carrot Individual Wrap': 0,
#  'Muffin - Mix - Mango Sour Cherry': 0,
#  'Muffin - Mix - Strawberry Rhubarb': 0,
#  'Muffin - Zero Transfat': 0,
#  'Muffin Batt - Ban Dream Zero': 0,
#  'Muffin Batt - Carrot Spice': 0,
#  'Muffin Carrot - Individual': 0,
#  'Muffin Mix - Banana Nut': 0,
#  'Muffin Mix - Blueberry': 0,
#  'Muffin Mix - Corn Harvest': 0,
#  'Muffin Mix - Oatmeal': 0,
#  'Muffin Puck Ww Carrot': 0,
#  'Muffins - Assorted': 0,
#  'Munchies Honey Sweet Trail Mix': 0,
#  'Mushroom - Chantrelle, Fresh': 0,
#  'Mushroom - Enoki, Fresh': 0,
#  'Mushroom - Lg - Cello': 0,
#  'Mushroom - Porcini Frozen': 0,
#  'Mushroom - Porcini, Dry': 0,
#  'Mushroom - Shitake, Dry': 0,
#  'Mushroom - White Button': 0,
#  'Mustard - Individual Pkg': 0,
#  'Mustard Prepared': 0,
#  'Nantucket - 518ml': 0,
#  'Napkin - Cocktail,beige 2 - Ply': 0,
#  'Napkin - Dinner, White': 0,
#  'Napkin White - Starched': 0,
#  'Nescafe - Frothy French Vanilla': 0,
#  'Noodles - Steamed Chow Mein': 0,
#  'Nori Sea Weed': 0,
#  'Nut - Cashews, Whole, Raw': 0,
#  'Nut - Pecan, Halves': 0,
#  'Nut - Pecan, Pieces': 0,
#  'Nut - Walnut, Pieces': 0,
#  'Nutmeg - Ground': 0,
#  'Oats Large Flake': 0,
#  'Ocean Spray - Ruby Red': 0,
#  'Octopus': 0,
#  'Oil - Coconut': 0,
#  'Oil - Olive': 0,
#  'Oil - Peanut': 0,
#  'Oil - Shortening,liqud, Fry': 0,
#  'Oil - Truffle, White': 0,
#  'Olives - Green, Pitted': 0,
#  'Olives - Kalamata': 0,
#  'Olives - Nicoise': 0,
#  'Onions - Cippolini': 0,
#  'Onions - Cooking': 0,
#  'Onions - Red Pearl': 0,
#  'Onions - White': 0,
#  'Orange - Blood': 0,
#  'Orange Roughy 4/6 Oz': 0,
#  'Oranges - Navel, 72': 0,
#  'Oyster - In Shell': 0,
#  'Oysters - Smoked': 0,
#  'Paper - Brown Paper Mini Cups': 0,
#  'Paper Cocktail Umberlla 80 - 180': 0,
#  'Parasol Pick Stir Stick': 0,
#  'Pasta - Agnolotti - Butternut': 0,
#  'Pasta - Angel Hair': 0,
#  'Pasta - Bauletti, Chicken White': 0,
#  'Pasta - Canelloni': 0,
#  'Pasta - Canelloni, Single Serve': 0,
#  'Pasta - Cannelloni, Sheets, Fresh': 0,
#  'Pasta - Cheese / Spinach Bauletti': 0,
#  'Pasta - Fett Alfredo, Single Serve': 0,
#  'Pasta - Fettuccine, Dry': 0,
#  'Pasta - Fettuccine, Egg, Fresh': 0,
#  'Pasta - Gnocchi, Potato': 0,
#  'Pasta - Linguini, Dry': 0,
#  'Pasta - Penne Primavera, Single': 0,
#  'Pasta - Penne, Rigate, Dry': 0,
#  'Pasta - Rotini, Dry': 0,
#  'Pasta - Spaghetti, Dry': 0,
#  'Paste - Black Olive': 0,
#  'Pastrami': 0,
#  'Pastry - Apple Large': 0,
#  'Pastry - Baked Cinnamon Stick': 0,
#  'Pastry - Baked Scones - Mini': 0,
#  'Pastry - Banana Tea Loaf': 0,
#  'Pastry - Cheese Baked Scones': 0,
#  'Pastry - Chocolate Chip Muffin': 0,
#  'Pastry - Chocolate Marble Tea': 0,
#  'Pastry - French Mini Assorted': 0,
#  'Pastry - Raisin Muffin - Mini': 0,
#  'Pate - Cognac': 0,
#  'Peach - Halves': 0,
#  'Peas Snow': 0,
#  'Pecan Raisin - Tarts': 0,
#  'Pepper - Green': 0,
#  'Pepper - Green Thai': 0,
#  'Pepper - Gypsy Pepper': 0,
#  'Pepper - Jalapeno': 0,
#  'Pepper - Orange': 0,
#  'Pepper - Pablano': 0,
#  'Pepper - Paprika, Hungarian': 0,
#  'Pepper - Red Bell': 0,
#  'Pepper - Red, Finger Hot': 0,
#  'Pepper - Roasted Red': 0,
#  'Pepper - Scotch Bonnet': 0,
#  'Pepper - Sorrano': 0,
#  'Pepper Squash': 0,
#  'Peppercorns - Pink': 0,
#  'Pernod': 0,
#  'Petite Baguette': 0,
#  'Pickles - Gherkins': 0,
#  'Pie Pecan': 0,
#  'Pie Shells 10': 0,
#  'Pimento - Canned': 0,
#  'Piping - Bags Quizna': 0,
#  'Plaintain': 0,
#  'Plastic Arrow Stir Stick': 0,
#  'Plastic Wrap': 0,
#  'Plasticforkblack': 0,
#  'Plate Pie Foil': 0,
#  'Pop - Club Soda Can': 0,
#  'Pork - Chop, Frenched': 0,
#  'Pork - Ground': 0,
#  'Pork - Shoulder': 0,
#  'Pork - Smoked Back Bacon': 0,
#  'Pork - Smoked Kassler': 0,
#  'Pork Loin Cutlets': 0,
#  'Pork Salted Bellies': 0,
#  'Potato - Sweet': 0,
#  'Potatoes - Mini White 3 Oz': 0,
#  'Potatoes - Parissienne': 0,
#  'Potatoes - Pei 10 Oz': 0,
#  'Potatoes - Purple, Organic': 0,
#  'Potatoes - Yukon Gold 5 Oz': 0,
#  'Potatoes - Yukon Gold, 80 Ct': 0,
#  'Propel Sport Drink': 0,
#  'Puff Pastry - Sheets': 0,
#  'Pumpkin - Seed': 0,
#  'Puree - Blackcurrant': 0,
#  'Puree - Guava': 0,
#  'Puree - Pear': 0,
#  'Puree - Raspberry': 0,
#  'Quail - Eggs, Fresh': 0,
#  'Quail Eggs - Canned': 0,
#  'Quiche Assorted': 0,
#  'Rabbit - Legs': 0,
#  'Radish': 0,
#  'Raspberries - Frozen': 0,
#  'Red Currants': 0,
#  'Remy Red': 0,
#  'Rice - 7 Grain Blend': 0,
#  'Rice - Basmati': 0,
#  'Rice - Brown': 0,
#  'Rice - Wild': 0,
#  'Roe - Flying Fish': 0,
#  'Roe - Lump Fish, Red': 0,
#  'Roe - White Fish': 0,
#  'Rolled Oats': 0,
#  'Rosemary - Fresh': 0,
#  'Rosemary - Primerba, Paste': 0,
#  'Rum - Cream, Amarula': 0,
#  'Rum - Dark, Bacardi, Black': 0,
#  'Rum - Light, Captain Morgan': 0,
#  'Russian Prince': 0,
#  'Sage - Rubbed': 0,
#  'Sage Derby': 0,
#  'Salad Dressing': 0,
#  'Salmon - Atlantic, Fresh, Whole': 0,
#  'Salmon - Atlantic, No Skin': 0,
#  'Salmon - Atlantic, Skin On': 0,
#  'Salmon - Canned': 0,
#  'Salmon - Fillets': 0,
#  'Salmon - Whole, 4 - 6 Pounds': 0,
#  'Salmon Steak - Cohoe 8 Oz': 0,
#  'Salt - Celery': 0,
#  'Salt - Seasoned': 0,
#  'Salt - Table': 0,
#  'Sansho Powder': 0,
#  'Sauce - Caesar Dressing': 0,
#  'Sauce - Fish 25 Ozf Bottle': 0,
#  'Sauce - Gravy, Au Jus, Mix': 0,
#  'Sauce - Plum': 0,
#  'Sauce - Roasted Red Pepper': 0,
#  'Sauce - Salsa': 0,
#  'Sauce - Soya, Dark': 0,
#  'Sauce - Thousand Island': 0,
#  'Sauerkraut': 0,
#  'Sausage - Chorizo': 0,
#  'Sausage - Liver': 0,
#  'Scallop - St. Jaques': 0,
#  'Scallops - 20/30': 0,
#  'Scallops - In Shell': 0,
#  'Scallops - Live In Shell': 0,
#  'Scallops - U - 10': 0,
#  'Schnappes Peppermint - Walker': 0,
#  'Sea Bass - Fillets': 0,
#  'Sea Bass - Whole': 0,
#  'Shopper Bag - S - 4': 0,
#  'Shrimp - 150 - 250': 0,
#  'Shrimp - 21/25, Peel And Deviened': 0,
#  'Shrimp - Baby, Cold Water': 0,
#  'Shrimp - Black Tiger 26/30': 0,
#  'Shrimp - Prawn': 0,
#  'Shrimp, Dried, Small / Lb': 0,
#  'Smoked Tongue': 0,
#  'Snails - Large Canned': 0,
#  'Snapple - Iced Tea Peach': 0,
#  'Snapple Lemon Tea': 0,
#  'Soap - Mr.clean Floor Soap': 0,
#  'Soap - Pine Sol Floor Cleaner': 0,
#  'Sobe - Green Tea': 0,
#  'Sobe - Liz Blizz': 0,
#  'Sobe - Tropical Energy': 0,
#  'Sole - Iqf': 0,
#  'Sorrel - Fresh': 0,
#  'Soup - Beef Conomme, Dry': 0,
#  'Soup - Beef, Base Mix': 0,
#  'Soup - Campbells - Chicken Noodle': 0,
#  'Soup - Campbells - Tomato': 0,
#  'Soup - Campbells Bean Medley': 0,
#  'Soup - Campbells Broccoli': 0,
#  'Soup - Campbells Mac N Cheese': 0,
#  'Soup - Campbells Mushroom': 0,
#  'Soup - Campbells Pasta Fagioli': 0,
#  'Soup - Campbells, Cream Of': 0,
#  'Soup - Clam Chowder, Dry Mix': 0,
#  'Soup - Cream Of Potato / Leek': 0,
#  'Soup - French Can Pea': 0,
#  'Soup - Knorr, Classic Can. Chili': 0,
#  'Soup - Knorr, Country Bean': 0,
#  'Soup Campbells Mexicali Tortilla': 0,
#  'Soup V8 Roasted Red Pepper': 0,
#  'Soupcontfoam16oz 116con': 0,
#  'Sour Puss Raspberry': 0,
#  'Spic And Span All Purpose': 0,
#  'Spice - Greek 1 Step': 0,
#  'Spice - Onion Powder Granulated': 0,
#  'Spice - Pepper Portions': 0,
#  'Spinach - Baby': 0,
#  'Spinach - Spinach Leaf': 0,
#  'Split Peas - Yellow, Dry': 0,
#  'Spring Roll Veg Mini': 0,
#  'Sprouts - Baby Pea Tendrils': 0,
#  'Sprouts - Pea': 0,
#  'Sproutsmustard Cress': 0,
#  'Squash - Guords': 0,
#  'Squid - U 5': 0,
#  'Squid U5 - Thailand': 0,
#  'Stainless Steel Cleaner Vision': 0,
#  'Star Anise, Whole': 0,
#  'Steam Pan Full Lid': 0,
#  'Stock - Beef, Brown': 0,
#  'Stock - Chicken, White': 0,
#  'Stock - Veal, Brown': 0,
#  'Straws - Cocktale': 0,
#  'Sugar - Invert': 0,
#  'Sugar - Palm': 0,
#  'Sugar - Sweet N Low, Individual': 0,
#  'Sugar - White Packet': 0,
#  'Sugar Thermometer': 0,
#  'Sultanas': 0,
#  'Sun - Dried Tomatoes': 0,
#  'Swordfish Loin Portions': 0,
#  'Syrup - Golden, Lyles': 0,
#  'Table Cloth 120 Round White': 0,
#  'Table Cloth 144x90 White': 0,
#  'Table Cloth 54x54 Colour': 0,
#  'Table Cloth 54x54 White': 0,
#  'Table Cloth 54x72 Colour': 0,
#  'Table Cloth 72x144 White': 0,
#  'Table Cloth 90x90 Colour': 0,
#  'Tahini Paste': 0,
#  'Taro Root': 0,
#  'Tart - Pecan Butter Squares': 0,
#  'Tart Shells - Barquettes, Savory': 0,
#  'Tart Shells - Savory, 4': 0,
#  'Tart Shells - Sweet, 3': 0,
#  'Tea - Decaf Lipton': 0,
#  'Tea - Earl Grey': 0,
#  'Tea - Grapefruit Green Tea': 0,
#  'Tea - Vanilla Chai': 0,
#  'Tea Peppermint': 0,
#  'Tendrils - Baby Pea, Organic': 0,
#  'Teriyaki Sauce': 0,
#  'The Pop Shoppe - Black Cherry': 0,
#  'The Pop Shoppe - Cream Soda': 0,
#  'The Pop Shoppe - Lime Rickey': 0,
#  'Thyme - Dried': 0,
#  'Thyme - Lemon, Fresh': 0,
#  'Tofu - Firm': 0,
#  'Tomato - Green': 0,
#  'Tomato - Plum With Basil': 0,
#  'Tomato Puree': 0,
#  'Tomatoes - Cherry': 0,
#  'Tomatoes - Roma': 0,
#  'Tomatoes Tear Drop': 0,
#  'Tomatoes Tear Drop Yellow': 0,
#  'Tortillas - Flour, 12': 0,
#  'Towel Dispenser': 0,
#  'Transfer Sheets': 0,
#  'Trueblue - Blueberry': 0,
#  'Truffle - Whole Black Peeled': 0,
#  'Truffle Cups - Red': 0,
#  'Truffle Cups - White Paper': 0,
#  'Truffle Cups Green': 0,
#  'Truffle Paste': 0,
#  'Tuna - Canned, Flaked, Light': 0,
#  'Turkey - Breast, Boneless Sk On': 0,
#  'Turkey - Breast, Double': 0,
#  'Turkey Tenderloin Frozen': 0,
#  'Turnip - White': 0,
#  'V8 Splash Strawberry Banana': 0,
#  'Vaccum Bag - 14x20': 0,
#  'Veal - Inside': 0,
#  'Veal - Leg': 0,
#  'Veal - Liver': 0,
#  'Veal - Provimi Inside': 0,
#  'Veal - Round, Eye Of': 0,
#  'Vector Energy Bar': 0,
#  'Venison - Racks Frenched': 0,
#  'Versatainer Nc - 888': 0,
#  'Versatainer Nc - 9388': 0,
#  'Vinegar - Champagne': 0,
#  'Vinegar - Cider': 0,
#  'Vinegar - Red Wine': 0,
#  'Vinegar - Tarragon': 0,
#  'Vinegar - White': 0,
#  'Vol Au Vents': 0,
#  'Wanton Wrap': 0,
#  'White Baguette': 0,
#  'White Fish - Filets': 0,
#  'Whmis - Spray Bottle Trigger': 0,
#  'Wiberg Cure': 0,
#  'Wine - Acient Coast Caberne': 0,
#  'Wine - Alsace Riesling Reserve': 0,
#  'Wine - Balbach Riverside': 0,
#  'Wine - Baron De Rothschild': 0,
#  'Wine - Beaujolais Villages': 0,
#  'Wine - Beringer Founders Estate': 0,
#  'Wine - Black Tower Qr': 0,
#  'Wine - Cahors Ac 2000, Clos': 0,
#  'Wine - Casablanca Valley': 0,
#  'Wine - Casillero Deldiablo': 0,
#  'Wine - Cava Aria Estate Brut': 0,
#  'Wine - Chablis 2003 Champs': 0,
#  'Wine - Chardonnay South': 0,
#  'Wine - Chenin Blanc K.w.v.': 0,
#  'Wine - Chianti Classica Docg': 0,
#  'Wine - Chianti Classico Riserva': 0,
#  'Wine - Cousino Macul Antiguas': 0,
#  'Wine - Domaine Boyar Royal': 0,
#  'Wine - Ej Gallo Sonoma': 0,
#  'Wine - Fat Bastard Merlot': 0,
#  'Wine - Fontanafredda Barolo': 0,
#  'Wine - Gewurztraminer Pierre': 0,
#  'Wine - Lou Black Shiraz': 0,
#  'Wine - Malbec Trapiche Reserve': 0,
#  'Wine - Masi Valpolocell': 0,
#  'Wine - Niagara,vqa Reisling': 0,
#  'Wine - Peller Estates Late': 0,
#  'Wine - Pinot Noir Latour': 0,
#  'Wine - Pinot Noir Pond Haddock': 0,
#  'Wine - Pinot Noir Stoneleigh': 0,
#  'Wine - Port Late Bottled Vintage': 0,
#  'Wine - Prosecco Valdobienne': 0,
#  'Wine - Puligny Montrachet A.': 0,
#  'Wine - Red, Cabernet Merlot': 0,
#  'Wine - Red, Cabernet Sauvignon': 0,
#  'Wine - Red, Colio Cabernet': 0,
#  'Wine - Red, Gallo, Merlot': 0,
#  'Wine - Red, Gamay Noir': 0,
#  'Wine - Red, Marechal Foch': 0,
#  'Wine - Redchard Merritt': 0,
#  'Wine - Remy Pannier Rose': 0,
#  'Wine - Riesling Alsace Ac 2001': 0,
#  'Wine - Rioja Campo Viejo': 0,
#  'Wine - Rosso Toscano Igt': 0,
#  'Wine - Ruffino Chianti': 0,
#  'Wine - Ruffino Chianti Classico': 0,
#  'Wine - Sake': 0,
#  'Wine - Sauvignon Blanc Oyster': 0,
#  'Wine - Savigny - Les - Beaune': 0,
#  'Wine - Semi Dry Riesling Vineland': 0,
#  'Wine - Sicilia Igt Nero Avola': 0,
#  'Wine - Soave Folonari': 0,
#  'Wine - Sogrape Mateus Rose': 0,
#  'Wine - Spumante Bambino White': 0,
#  'Wine - Tio Pepe Sherry Fino': 0,
#  'Wine - Tribal Sauvignon': 0,
#  'Wine - Two Oceans Sauvignon': 0,
#  'Wine - Vidal Icewine Magnotta': 0,
#  'Wine - White Cab Sauv.on': 0,
#  'Wine - White, French Cross': 0,
#  'Wine - White, Mosel Gold': 0,
#  'Wine La Vielle Ferme Cote Du': 0,
#  'Yeast Dry - Fermipan': 0,
#  'Yogurt - Assorted Pack': 0,
#  'Yogurt - Cherry, 175 Gr': 0,
#  'Yogurt - Plain': 0,
#  'Yukon Jack': 0,
#  'Zucchini - Mini, Green': 0}

# %%
sep_ord = df.groupby(["Order_no", "Prod_name"])["Prod_name"].count()
ord_nums = df['Order_no'].unique()

# %%
for num in ord_nums:
  for product in sep_ord[num].keys():
    for ad_product in sep_ord[num].keys():
      if ad_product != product:
        appearences[ad_product][product] += 1

# %%
appearences['Icecream Cone - Areo Chocolate']
# Out:
# {'Alize Sunset': 2,
#  'Amaretto': 4,
#  'Amarula Cream': 3,
#  'Anchovy In Oil': 7,
#  'Anisette - Mcguiness': 11,
#  'Appetizer - Assorted Box': 3,
#  'Appetizer - Cheese Bites': 6,
#  'Appetizer - Escargot Puff': 3,
#  'Appetizer - Mini Egg Roll, Shrimp': 5,
#  'Appetizer - Sausage Rolls': 3,
#  'Appetizer - Seafood Assortment': 8,
#  'Appetizer - Southwestern': 4,
#  'Apple - Granny Smith': 1,
#  'Apple - Macintosh': 7,
#  'Apricots - Halves': 3,
#  'Apricots Fresh': 5,
#  'Artichokes - Knobless, White': 4,
#  'Aspic - Amber': 5,
#  'Aspic - Clear': 3,
#  'Assorted Desserts': 5,
#  'Avocado': 1,
#  'Bacardi Limon': 2,
#  'Bacardi Mojito': 7,
#  'Bacon Strip Precooked': 3,
#  'Bag Clear 10 Lb': 6,
#  'Bagel - Sesame Seed Presliced': 2,
#  'Bagelers': 3,
#  'Bagels Poppyseed': 4,
#  'Baking Soda': 7,
#  'Banana - Leaves': 4,
#  'Bandage - Fexible 1x3': 6,
#  'Bar Bran Honey Nut': 3,
#  'Bar Special K': 2,
#  'Basil - Dry, Rubbed': 9,
#  'Basil - Fresh': 3,
#  'Basil - Pesto Sauce': 6,
#  'Beans - Butter Lrg Lima': 5,
#  'Beans - Fava Fresh': 9,
#  'Beans - Fava, Canned': 6,
#  'Beans - Kidney, Canned': 3,
#  'Beans - Turtle, Black, Dry': 4,
#  'Beef - Bones, Marrow': 2,
#  'Beef - Bresaola': 3,
#  'Beef - Diced': 7,
#  'Beef - Eye Of Round': 7,
#  'Beef - Ground Medium': 4,
#  'Beef - Ground, Extra Lean, Fresh': 4,
#  'Beef - Ox Tail, Frozen': 3,
#  'Beef - Prime Rib Aaa': 1,
#  'Beef - Rib Eye Aaa': 5,
#  'Beef - Roasted, Cooked': 4,
#  'Beef - Rouladin, Sliced': 3,
#  'Beef - Striploin': 4,
#  'Beef - Tenderloin': 3,
#  'Beef - Texas Style Burger': 2,
#  'Beef - Top Sirloin': 4,
#  'Beef - Top Sirloin - Aaa': 5,
#  'Beef Cheek Fresh': 1,
#  'Beef Dry Aged Tenderloin Aaa': 5,
#  'Beef Striploin Aaa': 6,
#  'Beef Wellington': 5,
#  'Beer - Corona': 4,
#  'Beer - Creemore': 6,
#  'Beer - Fruli': 4,
#  'Beer - Guiness': 2,
#  'Beer - Labatt Blue': 3,
#  'Beer - Molson Excel': 4,
#  'Beer - Paulaner Hefeweisse': 4,
#  'Beer - Pilsner Urquell': 8,
#  'Beer - Rickards Red': 3,
#  'Beer - Sleemans Cream Ale': 1,
#  'Beer - Sleemans Honey Brown': 2,
#  'Beer - Steamwhistle': 8,
#  'Beets': 4,
#  'Beets - Mini Golden': 4,
#  'Black Currants': 5,
#  'Blue Curacao - Marie Brizard': 7,
#  'Blueberries - Frozen': 4,
#  'Bok Choy - Baby': 6,
#  'Bols Melon Liqueur': 1,
#  'Boogies': 5,
#  'Bread - 10 Grain Parisian': 3,
#  'Bread - Dark Rye': 5,
#  'Bread - Dark Rye, Loaf': 2,
#  'Bread - Focaccia Quarter': 3,
#  'Bread - French Baquette': 5,
#  'Bread - Italian Sesame Poly': 8,
#  'Bread - Kimel Stick Poly': 5,
#  'Bread - Mini Hamburger Bun': 6,
#  'Bread - Multigrain Oval': 4,
#  'Bread - Multigrain, Loaf': 4,
#  'Bread - Olive Dinner Roll': 2,
#  'Bread - Pain Au Liat X12': 4,
#  'Bread - Pita': 4,
#  'Bread - Pumpernickle, Rounds': 4,
#  'Bread - Raisin': 7,
#  'Bread - Raisin Walnut Pull': 2,
#  'Bread - Rosemary Focaccia': 8,
#  'Bread - Triangle White': 5,
#  'Bread - Wheat Baguette': 5,
#  'Bread Base - Gold Formel': 3,
#  'Bread Base - Toscano': 3,
#  'Bread Cranberry Foccacia': 6,
#  'Bread Fig And Almond': 2,
#  'Breadfruit': 1,
#  'Broccoli - Fresh': 3,
#  'Brocolinni - Gaylan, Chinese': 8,
#  'Broom - Angled': 4,
#  'Broom - Push': 5,
#  'Broom And Brush Rack Black': 4,
#  'Buffalo - Short Rib Fresh': 2,
#  'Buffalo - Striploin': 9,
#  'Bulgar': 5,
#  'Butter - Pod': 4,
#  'Butter - Salted, Micro': 3,
#  'Butter - Unsalted': 3,
#  'Butter Balls Salted': 7,
#  'Cabbage - Green': 3,
#  'Cabbage - Nappa': 4,
#  'Cabbage - Savoy': 6,
#  'Cake - Cake Sheet Macaroon': 7,
#  'Cake - French Pear Tart': 6,
#  'Cake - Miini Cheesecake Cherry': 3,
#  'Cake - Sheet Strawberry': 1,
#  'Cake Sheet Combo Party Pack': 1,
#  'Calypso - Black Cherry Lemonade': 3,
#  'Campari': 10,
#  'Canadian Emmenthal': 4,
#  'Capers - Pickled': 4,
#  'Capon - Breast, Wing On': 3,
#  'Carbonated Water - Lemon Lime': 5,
#  'Carbonated Water - White Grape': 4,
#  'Carrots - Purple, Organic': 9,
#  'Carroway Seed': 0,
#  'Cattail Hearts': 5,
#  'Cauliflower': 4,
#  'Celery': 5,
#  'Celery Root': 3,
#  'Cheese - Augre Des Champs': 8,
#  'Cheese - Brie, Triple Creme': 4,
#  'Cheese - Camembert': 5,
#  'Cheese - Cottage Cheese': 6,
#  'Cheese - Cream Cheese': 0,
#  'Cheese - Fontina': 3,
#  'Cheese - Goat': 2,
#  'Cheese - Gouda Smoked': 4,
#  'Cheese - Grana Padano': 2,
#  'Cheese - Manchego, Spanish': 4,
#  'Cheese - Marble': 6,
#  'Cheese - Montery Jack': 4,
#  'Cheese - Mozzarella, Buffalo': 6,
#  'Cheese - Parmesan Grated': 2,
#  'Cheese - Perron Cheddar': 5,
#  'Cheese - Pied De Vents': 3,
#  'Cheese - Provolone': 6,
#  'Cheese - Sheep Milk': 3,
#  'Cheese - Shred Cheddar / Mozza': 4,
#  'Cheese - St. Andre': 5,
#  'Cheese - Stilton': 5,
#  'Cheese - Swiss': 8,
#  'Cheese - Victor Et Berthold': 3,
#  'Cheese Cloth': 5,
#  'Cheese Cloth No 100': 8,
#  'Cherries - Bing, Canned': 1,
#  'Cherries - Fresh': 1,
#  'Cherries - Frozen': 5,
#  'Cherries - Maraschino,jar': 6,
#  'Chevril': 3,
#  'Chicken - Base': 8,
#  'Chicken - Breast, 5 - 7 Oz': 7,
#  'Chicken - Diced, Cooked': 5,
#  'Chicken - Leg / Back Attach': 5,
#  'Chicken - Leg, Boneless': 3,
#  'Chicken - Whole Fryers': 6,
#  'Chicken - Wieners': 6,
#  'Chicken Giblets': 2,
#  'Chicken Thigh - Bone Out': 8,
#  'Chilli Paste, Hot Sambal Oelek': 4,
#  'Chinese Foods - Cantonese': 6,
#  'Chinese Foods - Thick Noodles': 5,
#  'Chinese Lemon Pork': 4,
#  'Chip - Potato Dill Pickle': 5,
#  'Chips - Potato Jalapeno': 2,
#  'Chips Potato Reg 43g': 4,
#  'Chocolate - Chips Compound': 3,
#  'Chocolate - Compound Coating': 7,
#  'Chocolate - Dark Callets': 6,
#  'Chocolate - Milk, Callets': 4,
#  'Chocolate - Pistoles, Lactee, Milk': 1,
#  'Chocolate - Pistoles, White': 7,
#  'Chocolate - Semi Sweet': 2,
#  'Chocolate - Semi Sweet, Calets': 4,
#  'Chocolate Liqueur - Godet White': 2,
#  'Chutney Sauce - Mango': 5,
#  'Cinnamon Buns Sticky': 3,
#  'Cinnamon Rolls': 6,
#  'Clam Nectar': 5,
#  'Cleaner - Lime Away': 7,
#  'Cleaner - Pine Sol': 2,
#  'Cocoa Butter': 4,
#  'Cocoa Powder - Dutched': 4,
#  'Cocoa Powder - Natural': 4,
#  'Coconut - Whole': 5,
#  'Coconut Milk - Unsweetened': 7,
#  'Cod - Black Whole Fillet': 4,
#  'Cod - Fillets': 8,
#  'Cod - Salted, Boneless': 2,
#  'Coffee - Cafe Moreno': 4,
#  'Coffee - Colombian, Portioned': 3,
#  'Coffee - Decafenated': 3,
#  'Coffee - Ristretto Coffee Capsule': 6,
#  'Coffee Cup 16oz Foam': 6,
#  'Coffee Decaf Colombian': 10,
#  'Coffee Swiss Choc Almond': 6,
#  'Cognac - Courvaisier': 2,
#  'Compound - Mocha': 3,
#  'Compound - Passion Fruit': 7,
#  'Compound - Rum': 5,
#  'Cookie - Oreo 100x2': 3,
#  'Cookie Dough - Chocolate Chip': 7,
#  'Cookies - Amaretto': 4,
#  'Cookies - Englishbay Chochip': 5,
#  'Cookies - Fortune': 4,
#  'Coriander - Ground': 6,
#  'Corn - Mini': 5,
#  'Corn - On The Cob': 6,
#  'Corn Meal': 5,
#  'Cornstarch': 2,
#  'Cotton Wet Mop 16 Oz': 2,
#  'Crab - Blue, Frozen': 4,
#  'Crab - Claws, Snow 16 - 24': 3,
#  'Crab - Meat': 3,
#  'Crackers - Graham': 6,
#  'Crackers - Soda / Saltins': 3,
#  'Crackers - Water': 3,
#  'Creme De Banane - Marie': 4,
#  'Creme De Menth - White': 4,
#  'Croissants Thaw And Serve': 3,
#  'Crush - Cream Soda': 3,
#  'Cumin - Whole': 8,
#  'Cup - 4oz Translucent': 7,
#  'Cup - 8oz Coffee Perforated': 4,
#  'Cup Translucent 9 Oz': 2,
#  'Curry Paste - Green Masala': 4,
#  'Dc - Frozen Momji': 4,
#  'Dc - Sakura Fu': 6,
#  'Devonshire Cream': 8,
#  'Dikon': 2,
#  'Dill Weed - Dry': 9,
#  'Dip - Tapenade': 1,
#  'Doilies - 5, Paper': 4,
#  'Doilies - 7, Paper': 4,
#  'Doilies - 8, Paper': 6,
#  'Dr. Pepper - 355ml': 3,
#  'Dried Apple': 8,
#  'Dried Cranberries': 6,
#  'Dried Peach': 2,
#  'Duck - Fat': 6,
#  'Duck - Legs': 7,
#  'Ecolab - Hand Soap Form Antibac': 2,
#  'Ecolab - Hobart Upr Prewash Arm': 9,
#  'Ecolab - Lime - A - Way 4/4 L': 4,
#  'Ecolab - Medallion': 2,
#  'Ecolab - Mikroklene 4/4 L': 2,
#  'Ecolab - Solid Fusion': 9,
#  'Ecolab Digiclean Mild Fm': 5,
#  'Eggplant - Asian': 3,
#  'Eggplant - Baby': 4,
#  'Eggplant Oriental': 1,
#  'Eggs - Extra Large': 2,
#  'Emulsifier': 6,
#  'Energy Drink': 6,
#  'Energy Drink - Franks Pineapple': 6,
#  'Extract - Rum': 4,
#  'Extract Vanilla Pure': 7,
#  'Fiddlehead - Frozen': 2,
#  'Filling - Mince Meat': 2,
#  'Filo Dough': 5,
#  'Fish - Atlantic Salmon, Cold': 7,
#  'Five Alive Citrus': 4,
#  'Flavouring - Orange': 8,
#  'Flavouring - Raspberry': 6,
#  'Flavouring Vanilla Artificial': 7,
#  'Flour - Buckwheat, Dark': 7,
#  'Flour - Corn, Fine': 6,
#  'Flour - Masa De Harina Mexican': 1,
#  'Flour - So Mix Cake White': 6,
#  'Flour - Strong': 5,
#  'Flour - Teff': 4,
#  'Flour Dark Rye': 3,
#  'Flower - Commercial Spider': 5,
#  'Flower - Daisies': 1,
#  'Flower - Dish Garden': 3,
#  'Flower - Leather Leaf Fern': 6,
#  'Flower - Potmums': 1,
#  'Foam Cup 6 Oz': 6,
#  'Foam Tray S2': 5,
#  'Foil Cont Round': 6,
#  'Fond - Chocolate': 5,
#  'Food Colouring - Blue': 6,
#  'Food Colouring - Pink': 4,
#  'Fork - Plastic': 5,
#  'French Pastries': 4,
#  'Fuji Apples': 7,
#  'Garbage Bag - Clear': 4,
#  'Garbage Bags - Black': 3,
#  'Garbage Bags - Clear': 1,
#  'Garlic Powder': 2,
#  'Gatorade - Orange': 4,
#  'Gelatine Leaves - Bulk': 6,
#  'Gelatine Leaves - Envelopes': 3,
#  'Gelatine Powder': 9,
#  'Gherkin': 5,
#  'Gin - Gilbeys London, Dry': 5,
#  'Glass - Wine, Plastic, Clear 5 Oz': 7,
#  'Glaze - Clear': 3,
#  'Glycerine': 6,
#  'Goat - Leg': 4,
#  'Goldschalger': 4,
#  'Gooseberry': 3,
#  'Goulash Seasoning': 6,
#  'Grouper - Fresh': 7,
#  'Haggis': 5,
#  'Ham - Cooked Bayonne Tinned': 5,
#  'Ham - Cooked Italian': 7,
#  'Ham - Procutinni': 7,
#  'Heavy Duty Dust Pan': 4,
#  'Higashimaru Usukuchi Soy': 6,
#  'Honey - Lavender': 8,
#  'Honey - Liquid': 3,
#  'Horseradish - Prepared': 6,
#  'Hot Chocolate - Individual': 6,
#  'Huck Towels White': 8,
#  'Huck White Towels': 6,
#  'Ice Cream - Fudge Bars': 5,
#  'Ice Cream Bar - Drumstick': 2,
#  'Ice Cream Bar - Hageen Daz To': 3,
#  'Icecream - Dstk Cml And Fdg': 300,
#  'Iced Tea - Lemon, 340ml': 3,
#  'Iced Tea - Lemon, 460 Ml': 5,
#  'Initation Crab Meat': 5,
#  'Instant Coffee': 6,
#  'Irish Cream - Baileys': 5,
#  'Irish Cream - Butterscotch': 4,
#  'Island Oasis - Magarita Mix': 2,
#  'Island Oasis - Pina Colada': 4,
#  'Island Oasis - Raspberry': 7,
#  'Island Oasis - Sweet And Sour Mix': 6,
#  'Island Oasis - Wildberry': 5,
#  'Jam - Apricot': 3,
#  'Jam - Blackberry, 20 Ml Jar': 7,
#  'Jam - Raspberry,jar': 6,
#  'Jam - Strawberry, 20 Ml Jar': 6,
#  'Jameson - Irish Whiskey': 4,
#  'Jello - Assorted': 3,
#  'Juice - Grapefruit, 341 Ml': 1,
#  'Juice - Mango': 1,
#  'Juice - Ocean Spray Kiwi': 0,
#  'Juice - Orange': 7,
#  'Juice - Orange 1.89l': 3,
#  'Juice - Orange, 341 Ml': 5,
#  'Juice - Orangina': 2,
#  'Juice - V8 Splash': 2,
#  'Kaffir Lime Leaves': 5,
#  'Kellogs Raisan Bran Bars': 3,
#  'Ketchup - Tomato': 7,
#  'Kiwano': 4,
#  'Kiwi': 3,
#  'Lamb - Bones': 3,
#  'Lamb - Leg, Bone In': 1,
#  'Lamb - Pieces, Diced': 2,
#  'Lamb - Sausage Casings': 8,
#  'Lamb - Shanks': 4,
#  'Lamb - Shoulder, Boneless': 7,
#  'Lamb - Whole, Frozen': 5,
#  'Lamb Rack Frenched Australian': 2,
#  'Lamb Shoulder Boneless Nz': 8,
#  'Latex Rubber Gloves Size 9': 4,
#  'Lemon Balm - Fresh': 3,
#  'Lemon Grass': 5,
#  'Lemonade - Pineapple Passion': 5,
#  'Lemons': 7,
#  'Lentils - Green, Dry': 5,
#  'Lentils - Red, Dry': 5,
#  'Lettuce - Baby Salad Greens': 3,
#  'Lettuce - Boston Bib - Organic': 3,
#  'Lettuce - Lambs Mash': 1,
#  'Lettuce - Romaine': 3,
#  'Lettuce - Treviso': 5,
#  'Lettuce Romaine Chopped': 4,
#  'Lid - 0090 Clear': 3,
#  'Lighter - Bbq': 0,
#  'Limes': 5,
#  'Liqueur Banana, Ramazzotti': 5,
#  'Loaf Pan - 2 Lb, Foil': 7,
#  'Lobster - Base': 6,
#  'Lobster - Cooked': 7,
#  'Lobster - Tail 6 Oz': 3,
#  'Longan': 5,
#  'Longos - Burritos': 1,
#  'Longos - Cheese Tortellini': 4,
#  'Longos - Chicken Cordon Bleu': 5,
#  'Longos - Chicken Curried': 5,
#  'Longos - Greek Salad': 7,
#  'Longos - Grilled Veg Sandwiches': 5,
#  'Lotus Leaves': 7,
#  'Lotus Root': 2,
#  'Lotus Rootlets - Canned': 4,
#  'Macaroons - Two Bite Choc': 2,
#  'Mace': 4,
#  'Madeira': 6,
#  'Maple Syrup': 6,
#  'Marzipan 50/50': 5,
#  'Mcgillicuddy Vanilla Schnap': 7,
#  'Mcguinness - Blue Curacao': 8,
#  'Meldea Green Tea Liquor': 4,
#  'Melon - Watermelon Yellow': 3,
#  'Mikes Hard Lemonade': 6,
#  'Milk - 2% 250 Ml': 5,
#  'Milk 2% 500 Ml': 5,
#  'Mini - Vol Au Vents': 6,
#  'Mint - Fresh': 4,
#  'Mints - Striped Red': 6,
#  'Miso Paste White': 3,
#  'Mix - Cocktail Strawberry Daiquiri': 3,
#  'Molasses - Fancy': 5,
#  'Monkfish - Fresh': 4,
#  'Monkfish Fresh - Skin Off': 3,
#  'Mop Head - Cotton, 24 Oz': 6,
#  'Mortadella': 3,
#  'Mountain Dew': 2,
#  'Mousse - Banana Chocolate': 5,
#  'Mousse - Mango': 8,
#  'Muffin - Carrot Individual Wrap': 4,
#  'Muffin - Mix - Mango Sour Cherry': 2,
#  'Muffin - Mix - Strawberry Rhubarb': 5,
#  'Muffin - Zero Transfat': 5,
#  'Muffin Batt - Ban Dream Zero': 5,
#  'Muffin Batt - Carrot Spice': 2,
#  'Muffin Carrot - Individual': 3,
#  'Muffin Mix - Banana Nut': 5,
#  'Muffin Mix - Blueberry': 5,
#  'Muffin Mix - Corn Harvest': 4,
#  'Muffin Mix - Oatmeal': 5,
#  'Muffin Puck Ww Carrot': 5,
#  'Muffins - Assorted': 3,
#  'Munchies Honey Sweet Trail Mix': 4,
#  'Mushroom - Chantrelle, Fresh': 4,
#  'Mushroom - Enoki, Fresh': 9,
#  'Mushroom - Lg - Cello': 7,
#  'Mushroom - Porcini Frozen': 6,
#  'Mushroom - Porcini, Dry': 7,
#  'Mushroom - Shitake, Dry': 7,
#  'Mushroom - White Button': 7,
#  'Mustard - Individual Pkg': 3,
#  'Mustard Prepared': 8,
#  'Nantucket - 518ml': 4,
#  'Napkin - Cocktail,beige 2 - Ply': 7,
#  'Napkin - Dinner, White': 3,
#  'Napkin White - Starched': 6,
#  'Nescafe - Frothy French Vanilla': 9,
#  'Noodles - Steamed Chow Mein': 7,
#  'Nori Sea Weed': 5,
#  'Nut - Cashews, Whole, Raw': 3,
#  'Nut - Pecan, Halves': 4,
#  'Nut - Pecan, Pieces': 2,
#  'Nut - Walnut, Pieces': 2,
#  'Nutmeg - Ground': 3,
#  'Oats Large Flake': 5,
#  'Ocean Spray - Ruby Red': 7,
#  'Octopus': 5,
#  'Oil - Coconut': 5,
#  'Oil - Olive': 4,
#  'Oil - Peanut': 2,
#  'Oil - Shortening,liqud, Fry': 1,
#  'Oil - Truffle, White': 5,
#  'Olives - Green, Pitted': 7,
#  'Olives - Kalamata': 2,
#  'Olives - Nicoise': 2,
#  'Onions - Cippolini': 1,
#  'Onions - Cooking': 4,
#  'Onions - Red Pearl': 8,
#  'Onions - White': 2,
#  'Orange - Blood': 5,
#  'Orange Roughy 4/6 Oz': 3,
#  'Oranges - Navel, 72': 7,
#  'Oyster - In Shell': 1,
#  'Oysters - Smoked': 8,
#  'Paper - Brown Paper Mini Cups': 5,
#  'Paper Cocktail Umberlla 80 - 180': 1,
#  'Parasol Pick Stir Stick': 4,
#  'Pasta - Agnolotti - Butternut': 8,
#  'Pasta - Angel Hair': 11,
#  'Pasta - Bauletti, Chicken White': 5,
#  'Pasta - Canelloni': 6,
#  'Pasta - Canelloni, Single Serve': 3,
#  'Pasta - Cannelloni, Sheets, Fresh': 5,
#  'Pasta - Cheese / Spinach Bauletti': 2,
#  'Pasta - Fett Alfredo, Single Serve': 4,
#  'Pasta - Fettuccine, Dry': 2,
#  'Pasta - Fettuccine, Egg, Fresh': 6,
#  'Pasta - Gnocchi, Potato': 3,
#  'Pasta - Linguini, Dry': 4,
#  'Pasta - Penne Primavera, Single': 10,
#  'Pasta - Penne, Rigate, Dry': 6,
#  'Pasta - Rotini, Dry': 5,
#  'Pasta - Spaghetti, Dry': 7,
#  'Paste - Black Olive': 6,
#  'Pastrami': 4,
#  'Pastry - Apple Large': 10,
#  'Pastry - Baked Cinnamon Stick': 7,
#  'Pastry - Baked Scones - Mini': 5,
#  'Pastry - Banana Tea Loaf': 7,
#  'Pastry - Cheese Baked Scones': 9,
#  'Pastry - Chocolate Chip Muffin': 1,
#  'Pastry - Chocolate Marble Tea': 7,
#  'Pastry - French Mini Assorted': 6,
#  'Pastry - Raisin Muffin - Mini': 2,
#  'Pate - Cognac': 4,
#  'Peach - Halves': 8,
#  'Peas Snow': 5,
#  'Pecan Raisin - Tarts': 10,
#  'Pepper - Green': 4,
#  'Pepper - Green Thai': 2,
#  'Pepper - Gypsy Pepper': 5,
#  'Pepper - Jalapeno': 5,
#  'Pepper - Orange': 5,
#  'Pepper - Pablano': 9,
#  'Pepper - Paprika, Hungarian': 3,
#  'Pepper - Red Bell': 7,
#  'Pepper - Red, Finger Hot': 4,
#  'Pepper - Roasted Red': 2,
#  'Pepper - Scotch Bonnet': 6,
#  'Pepper - Sorrano': 6,
#  'Pepper Squash': 4,
#  'Peppercorns - Pink': 6,
#  'Pernod': 6,
#  'Petite Baguette': 2,
#  'Pickles - Gherkins': 4,
#  'Pie Pecan': 2,
#  'Pie Shells 10': 4,
#  'Pimento - Canned': 6,
#  'Piping - Bags Quizna': 5,
#  'Plaintain': 0,
#  'Plastic Arrow Stir Stick': 2,
#  'Plastic Wrap': 5,
#  'Plasticforkblack': 1,
#  'Plate Pie Foil': 6,
#  'Pop - Club Soda Can': 2,
#  'Pork - Chop, Frenched': 5,
#  'Pork - Ground': 6,
#  'Pork - Shoulder': 8,
#  'Pork - Smoked Back Bacon': 2,
#  'Pork - Smoked Kassler': 4,
#  'Pork Loin Cutlets': 6,
#  'Pork Salted Bellies': 5,
#  'Potato - Sweet': 6,
#  'Potatoes - Mini White 3 Oz': 2,
#  'Potatoes - Parissienne': 5,
#  'Potatoes - Pei 10 Oz': 4,
#  'Potatoes - Purple, Organic': 5,
#  'Potatoes - Yukon Gold 5 Oz': 7,
#  'Potatoes - Yukon Gold, 80 Ct': 7,
#  'Propel Sport Drink': 3,
#  'Puff Pastry - Sheets': 3,
#  'Pumpkin - Seed': 5,
#  'Puree - Blackcurrant': 4,
#  'Puree - Guava': 4,
#  'Puree - Pear': 3,
#  'Puree - Raspberry': 3,
#  'Quail - Eggs, Fresh': 4,
#  'Quail Eggs - Canned': 6,
#  'Quiche Assorted': 5,
#  'Rabbit - Legs': 2,
#  'Radish': 2,
#  'Raspberries - Frozen': 7,
#  'Red Currants': 6,
#  'Remy Red': 8,
#  'Rice - 7 Grain Blend': 4,
#  'Rice - Basmati': 7,
#  'Rice - Brown': 4,
#  'Rice - Wild': 7,
#  'Roe - Flying Fish': 7,
#  'Roe - Lump Fish, Red': 1,
#  'Roe - White Fish': 7,
#  'Rolled Oats': 9,
#  'Rosemary - Fresh': 11,
#  'Rosemary - Primerba, Paste': 4,
#  'Rum - Cream, Amarula': 3,
#  'Rum - Dark, Bacardi, Black': 3,
#  'Rum - Light, Captain Morgan': 5,
#  'Russian Prince': 1,
#  'Sage - Rubbed': 3,
#  'Sage Derby': 5,
#  'Salad Dressing': 7,
#  'Salmon - Atlantic, Fresh, Whole': 4,
#  'Salmon - Atlantic, No Skin': 5,
#  'Salmon - Atlantic, Skin On': 6,
#  'Salmon - Canned': 4,
#  'Salmon - Fillets': 4,
#  'Salmon - Whole, 4 - 6 Pounds': 7,
#  'Salmon Steak - Cohoe 8 Oz': 8,
#  'Salt - Celery': 3,
#  'Salt - Seasoned': 7,
#  'Salt - Table': 6,
#  'Sansho Powder': 4,
#  'Sauce - Caesar Dressing': 4,
#  'Sauce - Fish 25 Ozf Bottle': 2,
#  'Sauce - Gravy, Au Jus, Mix': 6,
#  'Sauce - Plum': 8,
#  'Sauce - Roasted Red Pepper': 3,
#  'Sauce - Salsa': 4,
#  'Sauce - Soya, Dark': 3,
#  'Sauce - Thousand Island': 4,
#  'Sauerkraut': 2,
#  'Sausage - Chorizo': 11,
#  'Sausage - Liver': 3,
#  'Scallop - St. Jaques': 5,
#  'Scallops - 20/30': 4,
#  'Scallops - In Shell': 2,
#  'Scallops - Live In Shell': 3,
#  'Scallops - U - 10': 4,
#  'Schnappes Peppermint - Walker': 2,
#  'Sea Bass - Fillets': 5,
#  'Sea Bass - Whole': 5,
#  'Shopper Bag - S - 4': 2,
#  'Shrimp - 150 - 250': 2,
#  'Shrimp - 21/25, Peel And Deviened': 6,
#  'Shrimp - Baby, Cold Water': 5,
#  'Shrimp - Black Tiger 26/30': 2,
#  'Shrimp - Prawn': 2,
#  'Shrimp, Dried, Small / Lb': 9,
#  'Smoked Tongue': 5,
#  'Snails - Large Canned': 5,
#  'Snapple - Iced Tea Peach': 6,
#  'Snapple Lemon Tea': 4,
#  'Soap - Mr.clean Floor Soap': 3,
#  'Soap - Pine Sol Floor Cleaner': 9,
#  'Sobe - Green Tea': 8,
#  'Sobe - Liz Blizz': 5,
#  'Sobe - Tropical Energy': 8,
#  'Sole - Iqf': 3,
#  'Sorrel - Fresh': 2,
#  'Soup - Beef Conomme, Dry': 7,
#  'Soup - Beef, Base Mix': 4,
#  'Soup - Campbells - Chicken Noodle': 9,
#  'Soup - Campbells - Tomato': 4,
#  'Soup - Campbells Bean Medley': 4,
#  'Soup - Campbells Broccoli': 4,
#  'Soup - Campbells Mac N Cheese': 8,
#  'Soup - Campbells Mushroom': 6,
#  'Soup - Campbells Pasta Fagioli': 4,
#  'Soup - Campbells, Cream Of': 2,
#  'Soup - Clam Chowder, Dry Mix': 4,
#  'Soup - Cream Of Potato / Leek': 2,
#  'Soup - French Can Pea': 4,
#  'Soup - Knorr, Classic Can. Chili': 2,
#  'Soup - Knorr, Country Bean': 2,
#  'Soup Campbells Mexicali Tortilla': 5,
#  'Soup V8 Roasted Red Pepper': 4,
#  'Soupcontfoam16oz 116con': 3,
#  'Sour Puss Raspberry': 10,
#  'Spic And Span All Purpose': 8,
#  'Spice - Greek 1 Step': 3,
#  'Spice - Onion Powder Granulated': 4,
#  'Spice - Pepper Portions': 7,
#  'Spinach - Baby': 2,
#  'Spinach - Spinach Leaf': 1,
#  'Split Peas - Yellow, Dry': 4,
#  'Spring Roll Veg Mini': 3,
#  'Sprouts - Baby Pea Tendrils': 4,
#  'Sprouts - Pea': 5,
#  'Sproutsmustard Cress': 5,
#  'Squash - Guords': 5,
#  'Squid - U 5': 7,
#  'Squid U5 - Thailand': 6,
#  'Stainless Steel Cleaner Vision': 2,
#  'Star Anise, Whole': 3,
#  'Steam Pan Full Lid': 3,
#  'Stock - Beef, Brown': 4,
#  'Stock - Chicken, White': 10,
#  'Stock - Veal, Brown': 6,
#  'Straws - Cocktale': 6,
#  'Sugar - Invert': 4,
#  'Sugar - Palm': 4,
#  'Sugar - Sweet N Low, Individual': 5,
#  'Sugar - White Packet': 4,
#  'Sugar Thermometer': 2,
#  'Sultanas': 5,
#  'Sun - Dried Tomatoes': 7,
#  'Swordfish Loin Portions': 5,
#  'Syrup - Golden, Lyles': 8,
#  'Table Cloth 120 Round White': 4,
#  'Table Cloth 144x90 White': 6,
#  'Table Cloth 54x54 Colour': 3,
#  'Table Cloth 54x54 White': 3,
#  'Table Cloth 54x72 Colour': 4,
#  'Table Cloth 72x144 White': 3,
#  'Table Cloth 90x90 Colour': 6,
#  'Tahini Paste': 7,
#  'Taro Root': 4,
#  'Tart - Pecan Butter Squares': 5,
#  'Tart Shells - Barquettes, Savory': 7,
#  'Tart Shells - Savory, 4': 5,
#  'Tart Shells - Sweet, 3': 2,
#  'Tea - Decaf Lipton': 3,
#  'Tea - Earl Grey': 6,
#  'Tea - Grapefruit Green Tea': 4,
#  'Tea - Vanilla Chai': 4,
#  'Tea Peppermint': 2,
#  'Tendrils - Baby Pea, Organic': 5,
#  'Teriyaki Sauce': 6,
#  'The Pop Shoppe - Black Cherry': 5,
#  'The Pop Shoppe - Cream Soda': 2,
#  'The Pop Shoppe - Lime Rickey': 0,
#  'Thyme - Dried': 1,
#  'Thyme - Lemon, Fresh': 8,
#  'Tofu - Firm': 2,
#  'Tomato - Green': 9,
#  'Tomato - Plum With Basil': 7,
#  'Tomato Puree': 2,
#  'Tomatoes - Cherry': 5,
#  'Tomatoes - Roma': 4,
#  'Tomatoes Tear Drop': 8,
#  'Tomatoes Tear Drop Yellow': 8,
#  'Tortillas - Flour, 12': 7,
#  'Towel Dispenser': 2,
#  'Transfer Sheets': 3,
#  'Trueblue - Blueberry': 6,
#  'Truffle - Whole Black Peeled': 6,
#  'Truffle Cups - Red': 5,
#  'Truffle Cups - White Paper': 5,
#  'Truffle Cups Green': 2,
#  'Truffle Paste': 7,
#  'Tuna - Canned, Flaked, Light': 5,
#  'Turkey - Breast, Boneless Sk On': 3,
#  'Turkey - Breast, Double': 1,
#  'Turkey Tenderloin Frozen': 6,
#  'Turnip - White': 3,
#  'V8 Splash Strawberry Banana': 7,
#  'Vaccum Bag - 14x20': 3,
#  'Veal - Inside': 6,
#  'Veal - Leg': 5,
#  'Veal - Liver': 10,
#  'Veal - Provimi Inside': 4,
#  'Veal - Round, Eye Of': 7,
#  'Vector Energy Bar': 3,
#  'Venison - Racks Frenched': 7,
#  'Versatainer Nc - 888': 9,
#  'Versatainer Nc - 9388': 3,
#  'Vinegar - Champagne': 4,
#  'Vinegar - Cider': 7,
#  'Vinegar - Red Wine': 6,
#  'Vinegar - Tarragon': 3,
#  'Vinegar - White': 4,
#  'Vol Au Vents': 2,
#  'Wanton Wrap': 2,
#  'White Baguette': 6,
#  'White Fish - Filets': 8,
#  'Whmis - Spray Bottle Trigger': 6,
#  'Wiberg Cure': 3,
#  'Wine - Acient Coast Caberne': 6,
#  'Wine - Alsace Riesling Reserve': 5,
#  'Wine - Balbach Riverside': 4,
#  'Wine - Baron De Rothschild': 4,
#  'Wine - Beaujolais Villages': 10,
#  'Wine - Beringer Founders Estate': 5,
#  'Wine - Black Tower Qr': 8,
#  'Wine - Cahors Ac 2000, Clos': 3,
#  'Wine - Casablanca Valley': 4,
#  'Wine - Casillero Deldiablo': 6,
#  'Wine - Cava Aria Estate Brut': 3,
#  'Wine - Chablis 2003 Champs': 2,
#  'Wine - Chardonnay South': 7,
#  'Wine - Chenin Blanc K.w.v.': 6,
#  'Wine - Chianti Classica Docg': 8,
#  'Wine - Chianti Classico Riserva': 6,
#  'Wine - Cousino Macul Antiguas': 4,
#  'Wine - Domaine Boyar Royal': 8,
#  'Wine - Ej Gallo Sonoma': 3,
#  'Wine - Fat Bastard Merlot': 0,
#  'Wine - Fontanafredda Barolo': 4,
#  'Wine - Gewurztraminer Pierre': 5,
#  'Wine - Lou Black Shiraz': 4,
#  'Wine - Malbec Trapiche Reserve': 7,
#  'Wine - Masi Valpolocell': 12,
#  'Wine - Niagara,vqa Reisling': 7,
#  'Wine - Peller Estates Late': 3,
#  'Wine - Pinot Noir Latour': 7,
#  'Wine - Pinot Noir Pond Haddock': 7,
#  'Wine - Pinot Noir Stoneleigh': 7,
#  'Wine - Port Late Bottled Vintage': 3,
#  'Wine - Prosecco Valdobienne': 5,
#  'Wine - Puligny Montrachet A.': 6,
#  'Wine - Red, Cabernet Merlot': 4,
#  'Wine - Red, Cabernet Sauvignon': 3,
#  'Wine - Red, Colio Cabernet': 6,
#  'Wine - Red, Gallo, Merlot': 1,
#  'Wine - Red, Gamay Noir': 7,
#  'Wine - Red, Marechal Foch': 9,
#  'Wine - Redchard Merritt': 5,
#  'Wine - Remy Pannier Rose': 2,
#  'Wine - Riesling Alsace Ac 2001': 4,
#  'Wine - Rioja Campo Viejo': 4,
#  'Wine - Rosso Toscano Igt': 5,
#  'Wine - Ruffino Chianti': 4,
#  'Wine - Ruffino Chianti Classico': 11,
#  'Wine - Sake': 4,
#  'Wine - Sauvignon Blanc Oyster': 9,
#  'Wine - Savigny - Les - Beaune': 1,
#  'Wine - Semi Dry Riesling Vineland': 1,
#  'Wine - Sicilia Igt Nero Avola': 1,
#  'Wine - Soave Folonari': 1,
#  'Wine - Sogrape Mateus Rose': 2,
#  'Wine - Spumante Bambino White': 6,
#  'Wine - Tio Pepe Sherry Fino': 4,
#  'Wine - Tribal Sauvignon': 10,
#  'Wine - Two Oceans Sauvignon': 6,
#  'Wine - Vidal Icewine Magnotta': 4,
#  'Wine - White Cab Sauv.on': 6,
#  'Wine - White, French Cross': 5,
#  'Wine - White, Mosel Gold': 2,
#  'Wine La Vielle Ferme Cote Du': 9,
#  'Yeast Dry - Fermipan': 5,
#  'Yogurt - Assorted Pack': 6,
#  'Yogurt - Cherry, 175 Gr': 6,
#  'Yogurt - Plain': 7,
#  'Yukon Jack': 6,
#  'Zucchini - Mini, Green': 4}

# %%
max = 0
product = ''
product1 = ''
for key in appearences.keys():
  for key1 in appearences[key].keys():
    if appearences[key][key1] > max:
      product = key
      product1 = key1
      max = appearences[key][key1]

# %%
print("The products that are purchased together at the greatest number of orders are: '" + product + "' and '" + product1 + "'")
print("Number of times purchased together: " + str(max))
# Out:
# The products that are purchased together at the greatest number of orders are: 'Icecream Cone - Areo Chocolate' and 'Icecream - Dstk Cml And Fdg'
# Number of times purchased together: 300
